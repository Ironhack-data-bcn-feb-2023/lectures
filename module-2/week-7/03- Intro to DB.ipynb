# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Databases" data-toc-modified-id="Databases-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Databases</a></span></li><li><span><a href="#Different-tools-for-different-purposes" data-toc-modified-id="Different-tools-for-different-purposes-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Different tools for different purposes</a></span></li><li><span><a href="#Types-of-databases" data-toc-modified-id="Types-of-databases-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Types of databases</a></span></li><li><span><a href="#The-relational-model" data-toc-modified-id="The-relational-model-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>The relational model</a></span></li><li><span><a href="#Structured:" data-toc-modified-id="Structured:-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Structured:</a></span><ul class="toc-item"><li><span><a href="#Some-terms" data-toc-modified-id="Some-terms-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Some terms</a></span></li></ul></li><li><span><a href="#SQL" data-toc-modified-id="SQL-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>SQL</a></span><ul class="toc-item"><li><span><a href="#MySQL-vs-MongoDB" data-toc-modified-id="MySQL-vs-MongoDB-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>MySQL vs MongoDB</a></span></li><li><span><a href="#Relational-and-non-relational,-what-is-this?-🥸" data-toc-modified-id="Relational-and-non-relational,-what-is-this?-🥸-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Relational and non-relational, what is this? 🥸</a></span></li></ul></li><li><span><a href="#Query" data-toc-modified-id="Query-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Query</a></span></li><li><span><a href="#SQL-Sublanguages" data-toc-modified-id="SQL-Sublanguages-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>SQL Sublanguages</a></span></li><li><span><a href="#Relational-schemas" data-toc-modified-id="Relational-schemas-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Relational schemas</a></span></li><li><span><a href="#MySQL-data-types" data-toc-modified-id="MySQL-data-types-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>MySQL data types</a></span><ul class="toc-item"><li><span><a href="#Char" data-toc-modified-id="Char-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Char</a></span></li><li><span><a href="#Numeric" data-toc-modified-id="Numeric-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Numeric</a></span></li><li><span><a href="#Temporary-data" data-toc-modified-id="Temporary-data-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>Temporary data</a></span></li><li><span><a href="#Timestamp-vs-Datetime" data-toc-modified-id="Timestamp-vs-Datetime-10.4"><span class="toc-item-num">10.4&nbsp;&nbsp;</span>Timestamp vs Datetime</a></span></li><li><span><a href="#Some-acronyms" data-toc-modified-id="Some-acronyms-10.5"><span class="toc-item-num">10.5&nbsp;&nbsp;</span>Some acronyms</a></span></li></ul></li><li><span><a href="#Summary" data-toc-modified-id="Summary-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Summary</a></span></li><li><span><a href="#Further-Materials" data-toc-modified-id="Further-Materials-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Further Materials</a></span></li></ul></div>

# %% [markdown]
# # Introduction to Databases - MySQL

# %% [markdown]
# ![míticogif](https://media.giphy.com/media/G1ifnX4d5tYFACktp9/giphy.gif)

# %% [markdown]
# ## Databases

# %% [markdown]
# A database is nothing more than a collection of structured information.
#
# A phone book, for example, is a database of the names, phone numbers, and addresses of all the people who live in a given region. While a phone book is certainly a ubiquitous and frequently used database, it suffers from the following:
#
# - Finding a person's phone number can be time consuming, especially if the phone book contains a large number of entries.
#
# - The phone book is indexed only by surnames and first names, so finding the names of people who live at a given address, while possible in theory, is not a practical use for this database.
#
# - From the time the phone book is printed, the information becomes less and less accurate as people move in or out of a region, change their phone number, or move to another location within the same region.
#
# The same drawbacks that are attributed to telephone directories can be applied to any manual data storage system, such as patient records stored in a filing cabinet. Due to the cumbersome nature of paper databases, some of the first computer applications developed were database systems, which are computerized data storage and retrieval mechanisms. Because a database system stores data electronically instead of on paper, a database system is able to retrieve data faster, index data in multiple ways, and provide up-to-date information to its user community.
#
# Early database systems managed data stored on magnetic tape. Since there were typically many more tapes than tape readers, technicians were tasked with loading and unloading tapes as specific data was requested. Since computers at the time had very little memory, multiple requests for the same data often required the data to be read from tape multiple times. Although these database systems were a significant improvement over paper databases, they are a far cry from what is possible with current technology. (Modern database systems can handle petabytes of data, accessed by clusters of servers that each store tens of gigabytes of that data in high-speed memory, but I'm getting a little ahead of myself.)

# %% [markdown]
# ## Different tools for different purposes
#
# - ETL: SQL, MongoDB; APIs, web-scrapping, Python
# - Querying: SQL, Python
# - Visualization: Seaborn, Matplotlib, Plotly & Tableau
# - Machine Learning: Python

# %% [markdown]
# ## Types of databases

# %% [markdown]
# - Relational
# - Non-relational

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## The relational model
# In 1970, Dr. E. F. Codd of the IBM Research Laboratory published a paper entitled "A Relational Model of Data for Large Shared Data Banks" in which he proposed that The data will be represented as sets of tables. Instead of using pointers to navigate between related entities, redundant data is used to link records in different tables. Figure 1-3 shows how George and Sue's account information would appear in this context.

# %% [markdown]
# ![sql1](../../images/sql1.png)

# %% [markdown]
# The image represents the four tables discussed so far: customer, product, account, and transaction. Looking at the top of the customer table in Figure 1-3, you can see three columns:
#
# - cust_id (which contains the customer's identification number)
# - fname (which contains the customer's name)
# - lname (containing the customer's last name).
#
#
# If you look at the customer side of the table, you can see two rows, one containing George Blake's data and the other containing Sue Smith's data. The number of columns that a table can contain differs from server to server, but is usually large enough that it is not a problem (Microsoft SQL Server, for example, allows up to 1,024 columns per table). The number of rows a table can hold depends more on physical limits (that is, the space available on the disk drive) and maintainability (that is, how large a table can grow before it becomes difficult to work with it) than the limitations of the database server.
#
# Each table in a relational database includes information that uniquely identifies a row in that table (known as a primary key) or at least it should; along with additional information needed to fully describe the entity. Going back to the customers table, the cust_id column contains a different number for each customer; George Blake, for example, can be uniquely identified by customer ID 1. No other customers will be assigned that identifier, and no other information is needed to locate George Blake's data in the customer table.

# %% [markdown]
# # ✏️ Let's get to work! - Activity
#
# Conduct some research on the differences between structured and unstructured data. You can use the following link for reference: https://www.datamation.com/big-data/structured-vs-unstructured-data.html. Feel free to use any other resource as well.
#
# Every student would explain one difference to the other students in class.

# %% [markdown]
# Structured vs unstructured
#
# ## Structured:

# %% [markdown]
# ### Some terms

# %% [markdown]
# - **Entity**: Each table has a series of fields that represent values ​​that we want to store for each entity. For example, a product has the following attributes that are translated into the corresponding fields to store its information: in this case, Name, Surname, product_cd, cust_id....
#
# - **Column**: An individual piece of data stored in a table.
#
# - **Row**: A set of columns that together fully describe an entity or some action on an entity. Also called registration.
#
# - **Table**: A set of rows that is kept in memory (non-persistent) or in permanent storage (persistent).
#
# - **Result set**: Another name for a non-persistent table, usually the result of an SQL query.
#
# - **Primary Key** (PK): One or more columns that can be used as a unique identifier for each row in a table.
#
# - **Foreign Key** (FK): One or more columns that can be used together to identify a row in another table.

# %% [markdown]
# ## SQL

# %% [markdown]
# **S**tructured **Q**uery **L**anguage is a standard database language used to create, manage, and query database data relational data

# %% [markdown]
# To interact with the physical object that is the database, we use software (programs) called **DBMS**.
# During the bootcamp we will learn two of the best known and used:
# - **R**elational **D**atabase **M**anagement **S**ystem (RDBMS) ----> MySQL
# - **N**on-**R**elational **D**atabase **M**anagement **S**(NRDBMS) ----> mongoDB

# %% [markdown]
# ### MySQL vs MongoDB

# %% [markdown]
# ![mysql_vs_mongodb](https://blog.panoply.io/hs-fs/hubfs/MySQL%20vs%20MongoDB.png?width=750&height=317&name=MySQL%20vs%20MongoDB.png)

# %% [markdown]
# I leave you [here](https://blog.panoply.io/mongodb-and-mysql) the link to the article

# %% [markdown]
# ### Relational and non-relational, what is this? 🥸

# %% [markdown]
# **Relational** databases:
# - They are based on relational algebra
# - Store information in tabular form
# - Use SQL

# %% [markdown]
# ![relacionales](https://ayudaleyprotecciondatos.es/wp-content/uploads/2020/09/Modelo-base-de-datos-relacional.jpg)

# %% [markdown]
# **Non-relational** databases
# - Store data in non-tabular form ("documents")
# - They use NoSQL

# %% [markdown]
# ![norelacional](https://aukera.es/blog/imagenes/tabla-codigo.png)

# %% [markdown]
# These databases have become very popular in recent years, you can build the database in a more organic way because it is much more flexible.

# %% [markdown]
# ![sorpresa](../images/no-database.png)

# %% [markdown]
# # ✏️ Let's get to work!
#
# List at least three advantages of relational databases over data stored in for eg. excel sheets, google spreadsheets, and other files such as .txt, .csv, etc. Hint: For eg., different tools have been developed to work with relational databases to query data. You can also talk about ACID principles (Google is your friend. 😉).

# %% [markdown]
# [Why shouldn't we use excel as a database?](https://www.bbc.com/news/technology-54423988)

# %% [markdown]
# ## Query

# %% [markdown]
# We have seen at the beginning that SQL meant **S**tructured **Q**uery **L**language...
# Query is "query", it is a piece of code that we use to connect to the database and extract data.
# For example, how many products are there in my database?
# ```SQL
# SELECT COUNT (product_id) FROM products;
# ```
#
# But... we are not always going to perform queries to "get information" from our database, but sometimes we are also going to use queries to enter data.

# %% [markdown]
# ## SQL Sublanguages

# %% [markdown]
# - **Data Definition Language (DDL)** : refers to the part of the language that we use to define the structures for data storage.
#
# - **Data Manipulation Language (DML)** : DML we can manipulate the data itself, making queries to recover data, modifications, deletions, etc. There are four fundamental data manipulation operations and consequently four DML commands that we will need to be able to carry them out (now we see them)
#
# - **Data Control Language (DCL)** : much less known than the previous ones, this language is made up of specific statements to guarantee the security of access to data, facilitating user management and the granting or denial of rights. the necessary permissions to operate each element of the database.
#
# - **Transaction Control Language (TCL)** : TCL (Transactional Control Language): Allows managing different transactions that occur within a database. (Not used much in MySQL.)

# %% [markdown]
# **DDL**
# ```SQL
#
# CREATE : Used to create new tables, fields and indexes.
#
# ALTER : Used to modify the tables by adding fields or changing the definition of the fields.
#
# DROP : Used to drop tables and indexes.
#
# TRUNCATE : Used to remove all records from a table.
#
# RENAME : As its name indicates, it is used to rename objects.
#
# ```

# %% [markdown]
# **DML**
#
# ```SQL
# SELECT : The DML statement is used to execute a data retrieval query.
#
# INSERT : Its purpose is to insert new rows into a table.
#
# UPDATE : With this command it is possible to change the information stored in one or more rows.
#
# DELETE: It is used to delete one or more rows.
# ```

# %% [markdown]
# **MCD**
# ```SQL
# GRANT : Gives permissions to the database
#
# REVOKE : Revoke permissions to the database
# ```

# %% [markdown]
# **TCL**
# ```SQL
# COMMIT: Save the changes we have made in the database, they cannot be undone.
#
# ROLLBACK: Revert changes to the state of the last commit
#
# ```
# We're not going to use it, because MySQL has autocommit and anything we do directly gets saved in the database. But you must know that it exists.

# %% [markdown]
# ![resumen](../../images/resumen.png)

# %% [markdown]
# ## Relational schemas

# %% [markdown]
# We use a relational schema to describe what our database looks like. The key components of any relational schema are:
#
# ![relaciones](../images/relaciones.png)
#
# Note: [here](https://towardsdatascience.com/designing-a-relational-database-and-creating-an-entity-relationship-diagram-89c1c19320b2) you have a super nice series of posts on towardsdatascience where these concepts are discussed.

# %% [markdown]
# **Primary Key** (pk)
# An attribute (or set of attributes) whose value exists (cannot be null) and is unique for each record in a table.
# Each table can have one and only one primary key. They are the unique identifiers of a table.

# %% [markdown]
# **Foreign Keys** (fk)
# A column (or a set of columns) that identifies the relationship between one (child) table and another (parent) --through the parent's primary key.

# %% [markdown]
# Relations indicate the amount of data from a foreign key that can be seen in the primary key column(s) of the table to which the data is related, and vice versa. There are three main types:
#
# - one-to-one
# - one-to-many
# - many-to-many
#
# Note: The process of defining these relationships is often called normalization.

# %% [markdown]
# ## MySQL data types
# In general, all popular database servers have the ability to store the same types of data, such as strings, dates, and numbers. Where they tend to differ is in special data types, such as XML and JSON documents or spatial data. We will talk about the basic and most used data types:
# - char
# - numeric
# - date

# %% [markdown]
# ### Char

# %% [markdown]
# Character data can be stored as fixed- or variable-length strings; the difference is that fixed-length strings are padded with spaces on the right and always consume the same number of bytes, and variable-length strings are not padded with spaces on the right and do not always consume the same number of bytes. When defining a character column, you must specify the maximum size of any string to be stored in the column. For example, if you want to store strings up to 20 characters long, you can use any of the following definitions:
#
# ```SQL
# char(20) /*fixed-length*/
# varchar(20) /*variable-length*/
# ```
# The maximum length of char columns is currently 255 bytes, while varchar columns can be up to 65,535 bytes. If you need to store longer strings (such as emails, XML documents, etc.), then you'll want to use one of the text types (mediumtext and longtext).
# In general, you should use the char type when all the strings to be stored in the column are the same length, such as state abbreviations, and the varchar type when the strings to be stored in the column are of different lengths. . Both char and varchar are used in a similar way by all major database servers.
#
# ```SQL
# TINYTEXT
# TEXT
# MEDIUMTEXT
# LONGTEXT
# ```

# %% [markdown]
# ### Numeric

# %% [markdown]
# Although it might seem reasonable to have a single numeric data type called "numeric", there are actually several different numeric data types that reflect the various ways that numbers are used, as illustrated here:

# %% [markdown]
# ![int](../../images/int.png)
# ![float](../../images/float.png)

# %% [markdown]
# ### Temporary data
# Along with strings and numbers, you'll almost certainly be working with date and/or time information. This type of data is called temporary, and some examples of temporary data in a database are:
#
# - The future date when a particular event is expected to occur, such as the shipment of a customer order
# - The date a customer's order was shipped
# - The date and time a user modified a particular row in a table
# - An employee's date of birth
# - The year corresponding to a row in a yearly_sales fact table in a data warehouse
# - The elapsed time to complete a harness on a car assembly line
#
# MySQL includes data types to handle all these situations. The image below shows the temporary data types supported by MySQL.

# %% [markdown]
# ![temporales](../../images/temporal.png)

# %% [markdown]
# ### Timestamp vs Datetime

# %% [markdown]
# ### Some acronyms

# %% [markdown]
# PK - Primary Key
#
# NN - Not Null
#
# BIN - Binary (stores data as binary strings. There is no character set so sorting and comparison is based on the numeric values of the bytes in the values.)
#
# UN - Unsigned (non-negative numbers only. so if the range is -500 to 500, instead its 0 - 1000, the range is the same but it starts at 0)
#
# UQ - Unique Key
#
# ZF - Zero-Filled (if the length is 5 like INT(5) then every field is filled with 0’s to the 5th digit. 12 = 00012, 400 = 00400, etc. )
#
# AI - Auto Increment
#
# G - Generated column. i.e. value generated by a formula based on the other columns

# %% [markdown]
# # ✏️ Let's get to work
#
# We'll try to draw the data storage scheme of:
# - Spotify
# - Twitter
# - Zara

# %% [markdown]
# # EER: Entity relationship diagram

# %% [markdown]
# **On MySQL workbench**
#
#  - `CREATE DATABASE IF NOT EXISTS test`
#  - Database > Reverse engineer
#  - Select a database
#  - Click on continue

# %%
# What would the tables be
# What would the columns be
# What the relationship between them

# %%
# Spotify
    # Songs
    # Playlists
    # Users

# %%
# Twitter
    # tweets
    # users
    # retweets?
    # likes
    # hashtags

# %%
# Zara
    # locations
    # items
    # sales
    # employees

# %% [markdown]
# ## Summary
# Your turn, what have we learned today?

# %% [markdown]
# ## Further Materials
#
# - https://towardsdatascience.com/designing-a-relational-database-and-creating-an-entity-relationship-diagram-89c1c19320b2
# - [What is a database? What is SQL?](https://www.guru99.com/introduction-to-database-sql.html)
# - [Data Types: Structured vs. Unstructured Data - brief](https://www.bigdataframework.org/data-types-structured-vs-unstructured-data/)
# - [Database vs. Data Warehouse: key differences](https://www.guru99.com/database-vs-data-warehouse.html)
# - [video - What is Normalization in SQL? | Database Normalization Forms - 1NF, 2NF, 3NF, BCNF](https://www.youtube.com/watch?v=ABwD8IYByfk)
# - [Medium - Database Normalization Explained](https://towardsdatascience.com/database-normalization-explained-53e60a494495)
# - [SQL - DML (Data Manipulation Language) commands](https://www.nextstep4it.com/dml-commands-in-mysql/)
# - [video - SQL Data Manipulation Language INSERT / UPDATE / SELECT / DELETE](https://www.youtube.com/watch?v=5dszS8TxTJ4)
# - [DB normalization](https://en.wikipedia.org/wiki/Database_normalization)
