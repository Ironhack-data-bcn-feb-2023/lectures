# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Intro-to-Folium" data-toc-modified-id="Intro-to-Folium-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Intro to Folium</a></span></li></ul></li><li><span><a href="#1st-map:-Landmarks---Sonora-🌯" data-toc-modified-id="1st-map:-Landmarks---Sonora-🌯-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>1st map: Landmarks - Sonora 🌯</a></span><ul class="toc-item"><li><span><a href="#1st-Marker:-Landmarks:-Razzmatazz-🕺" data-toc-modified-id="1st-Marker:-Landmarks:-Razzmatazz-🕺-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>1st Marker: Landmarks: Razzmatazz 🕺</a></span><ul class="toc-item"><li><span><a href="#Now-different-icons" data-toc-modified-id="Now-different-icons-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Now different icons</a></span></li></ul></li><li><span><a href="#2nd-Marker:-beach" data-toc-modified-id="2nd-Marker:-beach-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>2nd Marker: beach</a></span></li></ul></li><li><span><a href="#Don't-bike-during-work-days-🤕" data-toc-modified-id="Don't-bike-during-work-days-🤕-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Don't bike during work-days 🤕</a></span></li><li><span><a href="#Morning-bikers-will-be-safer--🚴" data-toc-modified-id="Morning-bikers-will-be-safer--🚴-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Morning bikers will be safer  🚴</a></span><ul class="toc-item"><li><span><a href="#We-create-the-basic-map-to-which-we-then-add-the-layers" data-toc-modified-id="We-create-the-basic-map-to-which-we-then-add-the-layers-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>We create the basic map to which we then add the layers</a></span></li><li><span><a href="#Subset-the-dataframe-per-layer" data-toc-modified-id="Subset-the-dataframe-per-layer-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Subset the dataframe per layer</a></span></li><li><span><a href="#We-create-the-FeatureGroup" data-toc-modified-id="We-create-the-FeatureGroup-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>We create the FeatureGroup</a></span></li><li><span><a href="#Create-the-HeatMap-layer-and-add-it-to-the-FeatureGroup" data-toc-modified-id="Create-the-HeatMap-layer-and-add-it-to-the-FeatureGroup-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Create the HeatMap layer and add it to the FeatureGroup</a></span></li><li><span><a href="#Add-the-FeatureGroup-with-heatmap-and-name-to-the-map" data-toc-modified-id="Add-the-FeatureGroup-with-heatmap-and-name-to-the-map-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Add the FeatureGroup with heatmap and name to the map</a></span></li><li><span><a href="#Adding-the-evenings" data-toc-modified-id="Adding-the-evenings-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Adding the evenings</a></span></li><li><span><a href="#Night-layer" data-toc-modified-id="Night-layer-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Night layer</a></span></li><li><span><a href="#We-can-save-our-maps" data-toc-modified-id="We-can-save-our-maps-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>We can save our maps</a></span><ul class="toc-item"><li><span><a href="#Extra" data-toc-modified-id="Extra-3.8.1"><span class="toc-item-num">3.8.1&nbsp;&nbsp;</span>Extra</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ### Intro to Folium

# %% [markdown]
# ![mapa](../images/geo_portada.jpg)

# %% [markdown]
# First things first:
# - https://python-visualization.github.io/folium/

# %%
#!pip install folium

# %%
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import pandas as pd

# %% [markdown]
# ## 1st map: Landmarks - Sonora 🌯

# %% [markdown]
# We create a basic map as a result of some coordinates with an initial zoom

# %%
#sonora
#https://www.google.com/maps/place/Sonora+Sport+Tavern/@41.3978801,2.1877764,17z/data=!3m2!4b1!5s0x12a4a31ef25e7f6f:0x8534d14247dd8c4d!4m5!3m4!1s0x12a4a3192255e3c3:0x66d21ce6efad4cfb!8m2!3d41.3978801!4d2.1899704?hl=es

# %%
sonora_lat = 41.3978801
sonora_long = 2.1877764

# %%
map_1 = Map(location=[sonora_lat, sonora_long], zoom_start=15)

# %%
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a1aeba4d0a6fe6f5f4597e6520ea339 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a1aeba4d0a6fe6f5f4597e6520ea339&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a1aeba4d0a6fe6f5f4597e6520ea339 = L.map(
#                 &quot;map_1a1aeba4d0a6fe6f5f4597e6520ea339&quot;,
#                 {
#                     center: [41.3978801, 2.1877764],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b02c8e5b7c6b0b412e11e60f08d8c63 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1a1aeba4d0a6fe6f5f4597e6520ea339);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 1st Marker: Landmarks: Razzmatazz 🕺

# %%
razz_lat = 41.3970276
razz_long = 2.1893157

# %%
club = Marker(location = [razz_lat, razz_long], tooltip="Razzmatazz")

# %%
club.add_to(map_1)

# %%
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a1aeba4d0a6fe6f5f4597e6520ea339 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a1aeba4d0a6fe6f5f4597e6520ea339&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a1aeba4d0a6fe6f5f4597e6520ea339 = L.map(
#                 &quot;map_1a1aeba4d0a6fe6f5f4597e6520ea339&quot;,
#                 {
#                     center: [41.3978801, 2.1877764],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b02c8e5b7c6b0b412e11e60f08d8c63 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1a1aeba4d0a6fe6f5f4597e6520ea339);
#
#
#             var marker_b5283e9068a6f005190aeb924701146f = L.marker(
#                 [41.3970276, 2.1893157],
#                 {}
#             ).addTo(map_1a1aeba4d0a6fe6f5f4597e6520ea339);
#
#
#             marker_b5283e9068a6f005190aeb924701146f.bindTooltip(
#                 `&lt;div&gt;
#                      Razzmatazz
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# I leave you here the specific doc of the markers
# - https://python-visualization.github.io/folium/modules.html?highlight=marker

# %% [markdown]
# To add markers to a map, we'll have to "add" elements to that map, so we're going to add them to the previous map called map_1.

# %% [markdown]
# # How to get location:
#
# 1. Go to google maps
# 2. Look for something in particular
# 3. Look at the URL
#
# Example (after the @):
#
# https://www.google.com/maps/place/Sonora+Sport+Tavern/@41.3978841,2.1877817,17z/data=!3m2!4b1!5s0x12a4a31ef25e7f6f:0x8534d14247dd8c4d!4m5!3m4!1s0x12a4a3192255e3c3:0x66d21ce6efad4cfb!8m2!3d41.3978801!4d2.1899704

# %% [markdown]
# We add another Marker and we see that we can change the icon and the color of the background and the icon.

# %% [markdown]
# To modify the icons, where do we get them?
# - https://fontawesome.com/v4.7.0/icons/ --> If I want to use these I put prefix="fa" (Font Awesome)
# - https://getbootstrap.com/docs/3.3/components/ --> Built in no need to put prefix

# %% [markdown]
# ```python
# ['red', 'blue', 'green', 'purple', 'orange', 'darkred',
# 'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen', 'gray', 'black', 'lightgray ']
# ```

# %% [markdown]
# #### Now different icons

# %% [markdown]
# First way to add a tuned marker to the map

# %%
icon = Icon(color = "blue",
            opacity = 0.1,
            prefix = "fa",
            icon = "database",
            icon_color = "black"
)

# %%
ironhack = Marker(
    location = [41.3977737, 2.188262117],
    tooltip = "Ironhack",
    icon=icon
)

# %%
ironhack.add_to(map_1)

# %%
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a1aeba4d0a6fe6f5f4597e6520ea339 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a1aeba4d0a6fe6f5f4597e6520ea339&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a1aeba4d0a6fe6f5f4597e6520ea339 = L.map(
#                 &quot;map_1a1aeba4d0a6fe6f5f4597e6520ea339&quot;,
#                 {
#                     center: [41.3978801, 2.1877764],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b02c8e5b7c6b0b412e11e60f08d8c63 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1a1aeba4d0a6fe6f5f4597e6520ea339);
#
#
#             var marker_b5283e9068a6f005190aeb924701146f = L.marker(
#                 [41.3970276, 2.1893157],
#                 {}
#             ).addTo(map_1a1aeba4d0a6fe6f5f4597e6520ea339);
#
#
#             marker_b5283e9068a6f005190aeb924701146f.bindTooltip(
#                 `&lt;div&gt;
#                      Razzmatazz
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c46028beb7ea273130ab6299551290d3 = L.marker(
#                 [41.3977737, 2.188262117],
#                 {}
#             ).addTo(map_1a1aeba4d0a6fe6f5f4597e6520ea339);
#
#
#             var icon_a595a0cf08de4c0a53f26ff0c663113f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;database&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c46028beb7ea273130ab6299551290d3.setIcon(icon_a595a0cf08de4c0a53f26ff0c663113f);
#
#
#             marker_c46028beb7ea273130ab6299551290d3.bindTooltip(
#                 `&lt;div&gt;
#                      Ironhack
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ![Screenshot%202022-10-27%20at%2009.17.50.png](attachment:Screenshot%202022-10-27%20at%2009.17.50.png)

# %% [markdown]
# Second way to add a tuned marker to the map

# %% [markdown]
# ### 2nd Marker: beach

# %%
nova_icaria_lat, nova_icaria_long = 41.3901557, 2.2005327

# %%
nova_icaria_lat
# Out:
# 41.3901557

# %%
nova_icaria_long
# Out:
# 2.2005327

# %%
icon = Icon (
        color="blue",
        opacity = 0.6,
        prefix = "fa",
        icon="sun-o",
        color_icon = "black"
)

# %%
geo_dictionary = {
    "icon" : icon,
    "location" : [nova_icaria_lat, nova_icaria_long],
    "tooltip" : "Beach"
}

# %%
beach_marker = Marker (**geo_dictionary)

# %%
## Two ways: regular & kwargs

# 1st way:
ironhack = Marker(
    location = [41.3977737, 2.188262117],
    tooltip = "Ironhack",
    icon=icon
)



# 2nd way:
geo_dictionary = {
    "icon" : icon,
    "location" : [nova_icaria_lat, nova_icaria_long],
    "tooltip" : "Beach"
}
beach_marker = Marker (**geo_dictionary)

# %%
beach_marker.add_to(map_1)

# %%
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a1aeba4d0a6fe6f5f4597e6520ea339 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a1aeba4d0a6fe6f5f4597e6520ea339&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a1aeba4d0a6fe6f5f4597e6520ea339 = L.map(
#                 &quot;map_1a1aeba4d0a6fe6f5f4597e6520ea339&quot;,
#                 {
#                     center: [41.3978801, 2.1877764],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b02c8e5b7c6b0b412e11e60f08d8c63 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1a1aeba4d0a6fe6f5f4597e6520ea339);
#
#
#             var marker_b5283e9068a6f005190aeb924701146f = L.marker(
#                 [41.3970276, 2.1893157],
#                 {}
#             ).addTo(map_1a1aeba4d0a6fe6f5f4597e6520ea339);
#
#
#             marker_b5283e9068a6f005190aeb924701146f.bindTooltip(
#                 `&lt;div&gt;
#                      Razzmatazz
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c46028beb7ea273130ab6299551290d3 = L.marker(
#                 [41.3977737, 2.188262117],
#                 {}
#             ).addTo(map_1a1aeba4d0a6fe6f5f4597e6520ea339);
#
#
#             var icon_a595a0cf08de4c0a53f26ff0c663113f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;database&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c46028beb7ea273130ab6299551290d3.setIcon(icon_a595a0cf08de4c0a53f26ff0c663113f);
#
#
#             marker_c46028beb7ea273130ab6299551290d3.bindTooltip(
#                 `&lt;div&gt;
#                      Ironhack
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_02f8990e8b0f9afe95e8bf409b703269 = L.marker(
#                 [41.3901557, 2.2005327],
#                 {}
#             ).addTo(map_1a1aeba4d0a6fe6f5f4597e6520ea339);
#
#
#             var icon_59ec3624f3784fff56a91d51e3c41581 = L.AwesomeMarkers.icon(
#                 {&quot;colorIcon&quot;: &quot;black&quot;, &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;sun-o&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_02f8990e8b0f9afe95e8bf409b703269.setIcon(icon_59ec3624f3784fff56a91d51e3c41581);
#
#
#             marker_02f8990e8b0f9afe95e8bf409b703269.bindTooltip(
#                 `&lt;div&gt;
#                      Beach
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Kwargs --> https://book.pythontips.com/en/latest/args_and_kwargs.html
# https://j2logo.com/args-y-kwargs-en-python/

# %% [markdown]
# ## Don't bike during work-days 🤕

# %% [markdown]
# To teach this example, we use a dataset where we already have some latitude and longitude columns

# %%
df = pd.read_csv("datasets/bici_clean.csv")

# %%
df.horario.value_counts()
# Out:
# horario
# Tarde     1140
# Mañana     608
# Noche      449
# Name: count, dtype: int64

# %%
# tarde = evening
# mañana = morning
# noche = night


# lesividad: moderada, grave & leve (moderate, very bad, not so bad)

# FESTIVIDAD: 
    # festivo: holiday
    # laborable: working day
    # vispera: day before a holiday

# %%
df
# Out:
#                     fecha                  dia  year horario festividad
# 0     2019-01-01 14:00:00  2019-01-01 00:00:00  2019   Tarde    Festivo  \
# 1     2019-01-02 21:00:00  2019-01-02 00:00:00  2019   Noche  Laborable
# 2     2019-01-03 14:00:00  2019-01-03 00:00:00  2019   Tarde  Laborable
# 3     2019-01-03 13:00:00  2019-01-03 00:00:00  2019   Tarde  Laborable
# 4     2019-01-03 13:00:00  2019-01-03 00:00:00  2019   Tarde  Laborable
# ...                   ...                  ...   ...     ...        ...
# 2192  2017-12-26 18:00:00  2017-12-26 00:00:00  2017   Tarde  Laborable
# 2193  2017-12-27 00:00:00  2017-12-27 00:00:00  2017   Noche  Laborable
# 2194  2017-12-29 07:00:00  2017-12-29 00:00:00  2017  Mañana  Laborable
# 2195  2017-12-30 11:00:00  2017-12-30 00:00:00  2017  Mañana    Vispera
# 2196  2017-12-31 21:00:00  2017-12-31 00:00:00  2017   Noche    Festivo
#
#      tipo_accidente lesividad      meteo                        distrito
# 0          Colision  Moderada  Despejado                       SALAMANCA  \
# 1          Colision     Grave  Despejado                       HORTALEZA
# 2          Colision      Leve  Despejado               VILLA DE VALLECAS
# 3          Colision      Leve  Despejado               VILLA DE VALLECAS
# 4          Colision      Leve  Despejado               VILLA DE VALLECAS
# ...             ...       ...        ...                             ...
# 2192       Colision      Leve     Lluvia  RETIRO
# 2193          Caida      Leve     Lluvia  CHAMBERI
# 2194       Colision      Leve  Despejado  BARAJAS
# 2195          Caida      Leve  Despejado  CENTRO
# 2196       Colision      Leve     Lluvia  CHAMBERI
#
#                                               direccion       lon        lat
# 0     CALLE CASTELLO / CALLE DON RAMON DE LA CRUZ Ma... -3.681209  40.428990
# 1     AVDA. GRAN VIA DE HORTALEZA / GTA. LUIS ROSALE... -3.654527  40.466921
# 2                        CALLE FELIPE ALVAREZ 10 Madrid -3.623423  40.381971
# 3     AVDA. SANTA EUGENIA / CALLE REAL DE ARGANDA Ma... -3.608276  40.377939
# 4     AVDA. SANTA EUGENIA / CALLE REAL DE ARGANDA Ma... -3.608276  40.377939
# ...                                                 ...       ...        ...
# 2192  AVENIDA DE MENENDEZ PELAYO - CALLE DEL DOCE DE... -3.677848  40.415537
# 2193  CALLE DE FUENCARRAL NUM                       ... -3.702841  40.429487
# 2194  AVENIDA  SUR DEL AEROPUERTO DE BARAJAS - AVENI... -3.580041  40.456254
# 2195  CALLE DE LA MADERA NUM                        ... -3.703295  40.424769
# 2196  PASEO DE EDUARDO DATO NUM                     ... -3.696201  40.432461
#
# [2197 rows x 12 columns]

# %%
# number of markers can be the number of rows

# %%
# Madrid

mad_lat = 40.410815
mad_long = -3.70723119

# %%
madrid_map = Map(location = [mad_lat, mad_long], zoom_start = 15)

# %%
madrid_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abb4fb707282655c59287752d011fa07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abb4fb707282655c59287752d011fa07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abb4fb707282655c59287752d011fa07 = L.map(
#                 &quot;map_abb4fb707282655c59287752d011fa07&quot;,
#                 {
#                     center: [40.410815, -3.70723119],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_548d1f45fc090f04fcb1b90fb6a1847b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_abb4fb707282655c59287752d011fa07);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Overall all the accidents
# Moment of the day when they happen
# The days in which they happen:
    # working days will have more? more traffick
    # holidays have more because people go out and drink?

# %% [markdown]
# We are going to iterate over all the rows of the dataframe looking for what is inside each row in the column.
# We will put an icon to the accidents based on the "holiday" column
# But we will have to save the settings and add the Marker at the end and all this inside a loop 🤭🤯
# - First the tooltip config
# - Then the little icon depending on the holiday
# - Finally add each marker

# %%
#https://datos.madrid.es/portal/site/egob/menuitem.9e1e2f6404558187cf35cf3584f1a5a0/?vgnextoid=374512b9ace9f310VgnVCM100000171f5a0aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD&vgnextfmt=default

# %% [markdown]
# # iterating the dataframe
#     # if the row["festividad"] == "laborable":
#         icon something
#     # elif the row["festvidad"] == "vispera":
#         icon something else
#     # elif the row["festvidad"] == "Festivo":
#         icon something else else
#     # else:
#         else else else

# %%
# ITERATING A DF:

# big for loop: 
    # for i in df[["festividad"]]
    
# loop loc, iloc
    # for df["festividad"]:
        # if df["festividad"].loc["laborable"]
        
# subset?
    # subset for laborables
    # subset for festivos

# %% [markdown]
# # iterating the dataframe
#     # if the row["festividad"] == "laborable":
#         icon something
#     # elif the row["festvidad"] == "vispera":
#         icon something else
#     # elif the row["festvidad"] == "Festivo":
#         icon something else else
#     # else:
#         else else else

# %%
df.sample()
# Out:
#                    fecha                  dia  year horario festividad
# 427  2019-07-05 10:00:00  2019-07-05 00:00:00  2019  Mañana  Laborable  \
#
#     tipo_accidente lesividad      meteo         distrito
# 427          Caida      Leve  Despejado  MONCLOA-ARAVACA  \
#
#                        direccion       lon        lat
# 427  PUERTA PRINCIPAL ZOO Madrid -3.760959  40.409123

# %%
df.festividad.unique()
# Out:
# array(['Festivo', 'Laborable', 'Vispera'], dtype=object)

# %%
# I have the map
# Looping 
    # the df to create: ICONS
    # Each icon needs to be added to the map
    # MARKER:
        # icon
        # location
        # tooltip= distrito

# %%
madrid_map = Map(location = [mad_lat, mad_long], zoom_start = 15)

# %%
for index, row in df.iterrows():
    
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["distrito"]}
    
    #2. Icon
    if row["festividad"] == "Laborable":        
        icon = Icon (
            color="blue",
            opacity = 0.6,
            prefix = "fa",
            icon="briefcase",
            icon_color = "black"
        )
    elif row["festividad"] == "Vispera":
        icon = Icon (
            color="red",
            opacity = 0.6,
            prefix = "fa",
            icon="beer",
            icon_color = "yellow"
        )
    elif row["festividad"] == "Festivo":
        icon = Icon (
            color="darkpurple",
            opacity = 0.6,
            prefix = "fa",
            icon="bed",
            icon_color = "white"
        )
    else:
        icon = Icon (
            color="blue",
            opacity = 0.6,
            prefix = "fa",
            icon="question",
            icon_color = "brown",
            icon_size=(14, 14)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    
    #4. Add the Marker
    new_marker.add_to(madrid_map)

# %%
madrid_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bac90b75eb2b160de76300606e313512 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bac90b75eb2b160de76300606e313512&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bac90b75eb2b160de76300606e313512 = L.map(
#                 &quot;map_bac90b75eb2b160de76300606e313512&quot;,
#                 {
#                     center: [40.410815, -3.70723119],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11caba03c65d745f117106f88f56235f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bac90b75eb2b160de76300606e313512);
#
#
#             var marker_c6cdcd9b77cca804d9939d50365958b8 = L.marker(
#                 [40.4289896, -3.681209],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_bac90b75eb2b160de76300606e313512);
#
#
#             var icon_42cb85e89830974bb51ac6bdf10ca810 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bed&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkpurple&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c6cdcd9b77cca804d9939d50365958b8.setIcon(icon_42cb85e89830974bb51ac6bdf10ca810);
#
#
#             marker_c6cdcd9b77cca804d9939d50365958b8.bindTooltip(
#                 `&lt;div&gt;
#                      SALAMANCA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5d8135841924fdb3bf64390613097cdc = L.marker(
#                 [40.4669207, -3.6545272],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_bac90b75eb2b160de76300606e313512);
#
#
#             var icon_b42cae7e21155990586ab19cc7686613 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5d8135841924fdb3bf64390613097cdc.setIcon(icon_b42cae7e21155990586ab19cc7686613);
#
#
#             marker_5d8135841924fdb3bf64390613097cdc.bindTooltip(
#                 `&lt;div&gt;
#                      HORTALEZA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5027b0d86142e9012c6bd884998afad2 = L.marker(
#                 [40.3819706, -3.6234229],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_bac90b75eb2b160de76300606e313512);
#
#
#             var icon_bdc3cb705f56fba76b4836caee23e74b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5027b0d86142e9012c6bd884998afad2.setIcon(icon_bdc3cb705f56fba76b4836caee23e74b);
#
#
#             marker_5027b0d86142e9012c6bd884998afad2.bindTooltip(
#                 `&lt;div&gt;
#                      VILLA DE VALLECAS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e6d67f7e683d1ef592903cbe1e21d056 = L.marker(
#                 [40.377939000000005, -3.608275599999999],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_bac90b75eb2b160de76300606e313512);
#
#
#             var icon_78a4bfd8b9cec0cd20736532bc91020f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e6d67f7e683d1ef592903cbe1e21d056.setIcon(icon_78a4bfd8b9cec0cd20736532bc91020f);
#
#
#             marker_e6d67f7e683d1ef592903cbe1e21d056.bindTooltip(
#                 `&lt;div&gt;
#                      VILLA DE VALLECAS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0f030b0066928f72d479efed62a80dc9 = L.marker(
#                 [40.377939000000005, -3.608275599999999],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_bac90b75eb2b160de76300606e313512);
#
#
#             var icon_fdb1bc07678b7d7fe257db7a9ad61de3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &

# %% [markdown]
# Is that the best way to visualize this? We have created a map with infinite markers...but is there another way to visualize this information a little better?
# When we have a lot of grouped data 🗺

# %% [markdown]
# ##  Morning bikers will be safer  🚴

# %% [markdown]
# Let's check how many categories there are in the time column, to make a heat map. First we make a map with the morning schedule, and then we add the afternoon schedule with the Layer Control.
# Here we go 🔥

# %% [markdown]
# ### We create the basic map to which we then add the layers

# %%
madrid_map_2  = Map(location = [mad_lat, mad_long], zoom_start = 15)

# %%
madrid_map_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f706828de77210b915dbc10dbebb65cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f706828de77210b915dbc10dbebb65cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f706828de77210b915dbc10dbebb65cd = L.map(
#                 &quot;map_f706828de77210b915dbc10dbebb65cd&quot;,
#                 {
#                     center: [40.410815, -3.70723119],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b63239dc7761d6656f70bcf338f087d9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f706828de77210b915dbc10dbebb65cd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df["horario"].unique()
# Out:
# array(['Tarde', 'Noche', 'Mañana'], dtype=object)

# %% [markdown]
# ### Subset the dataframe per layer

# %%
morning = df[df["horario"]=="Mañana"]
morning.sample()
# Out:
#                    fecha                  dia  year horario festividad
# 407  2019-06-29 08:00:00  2019-06-29 00:00:00  2019  Mañana    Vispera  \
#
#     tipo_accidente lesividad      meteo             distrito
# 407       Colision      Leve  Despejado  FUENCARRAL-EL PARDO  \
#
#                                              direccion       lon        lat
# 407  GTA. SANTUARIO DE TISCAR / AVDA. MONASTERIO DE... -3.713252  40.503519

# %% [markdown]
# ### We create the FeatureGroup

# %%
morning_group = folium.FeatureGroup(name=f"Morning: {morning.shape[0]}")

# %% [markdown]
# ### Create the HeatMap layer and add it to the FeatureGroup

# %%
madrid_map_2  = Map(location = [mad_lat, mad_long], zoom_start = 15)
HeatMap(data=morning[["lat", "lon"]], 
        radius=25,
       gradient = {0.4: 'yellow', 0.65: 'orange', 1: 'white'}).add_to(morning_group)

# %% [markdown]
# ### Add the FeatureGroup with heatmap and name to the map

# %%
morning_group.add_to(madrid_map_2)

# %%
madrid_map_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f0a590a9184888762cddd817d1ce3d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f0a590a9184888762cddd817d1ce3d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f0a590a9184888762cddd817d1ce3d8 = L.map(
#                 &quot;map_0f0a590a9184888762cddd817d1ce3d8&quot;,
#                 {
#                     center: [40.410815, -3.70723119],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_604a2796648642be7ded460207246c17 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_