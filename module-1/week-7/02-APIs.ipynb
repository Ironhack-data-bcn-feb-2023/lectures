# %% [markdown]
# # APIS

# %% [markdown]
# ![apis_gif](https://media.giphy.com/media/wepUQluC5smgEd4Qz4/giphy.gif)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Libraries-summary" data-toc-modified-id="Libraries-summary-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Libraries summary</a></span></li><li><span><a href="#Internet,-DNS,-IPs" data-toc-modified-id="Internet,-DNS,-IPs-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Internet, DNS, IPs</a></span></li><li><span><a href="#HTTP" data-toc-modified-id="HTTP-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>HTTP</a></span><ul class="toc-item"><li><span><a href="#URL" data-toc-modified-id="URL-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>URL</a></span></li><li><span><a href="#HTTP-vs-HTTPS" data-toc-modified-id="HTTP-vs-HTTPS-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>HTTP vs HTTPS</a></span></li><li><span><a href="#Requests" data-toc-modified-id="Requests-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Requests</a></span></li><li><span><a href="#Response" data-toc-modified-id="Response-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Response</a></span></li></ul></li><li><span><a href="#API" data-toc-modified-id="API-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>API</a></span><ul class="toc-item"><li><span><a href="#RESTful-APIs" data-toc-modified-id="RESTful-APIs-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>RESTful APIs</a></span></li></ul></li><li><span><a href="#Let's-go" data-toc-modified-id="Let's-go-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Let's go</a></span><ul class="toc-item"><li><span><a href="#Requests-in-Python" data-toc-modified-id="Requests-in-Python-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Requests in Python</a></span></li><li><span><a href="#HTML-response" data-toc-modified-id="HTML-response-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>HTML response</a></span></li><li><span><a href="#JSON-response" data-toc-modified-id="JSON-response-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>JSON response</a></span></li><li><span><a href="#Data-management-in-pandas" data-toc-modified-id="Data-management-in-pandas-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Data management in pandas</a></span></li><li><span><a href="#Parameters" data-toc-modified-id="Parameters-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Parameters</a></span></li><li><span><a href="#Mini-recap" data-toc-modified-id="Mini-recap-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Mini-recap</a></span></li></ul></li><li><span><a href="#It's-now-your-turn" data-toc-modified-id="It's-now-your-turn-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>It's now your turn</a></span></li><li><span><a href="#STEPS-TO-GET-REPONSES" data-toc-modified-id="STEPS-TO-GET-REPONSES-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>STEPS TO GET REPONSES</a></span></li><li><span><a href="#STEPS-TO-MANIPULATE-THE-RESPONSES" data-toc-modified-id="STEPS-TO-MANIPULATE-THE-RESPONSES-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>STEPS TO MANIPULATE THE RESPONSES</a></span></li><li><span><a href="#Headers" data-toc-modified-id="Headers-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Headers</a></span></li><li><span><a href="#API-Keys-/-tokens-/-private_keys" data-toc-modified-id="API-Keys-/-tokens-/-private_keys-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>API Keys / tokens / private_keys</a></span></li><li><span><a href="#API-Clients" data-toc-modified-id="API-Clients-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>API Clients</a></span><ul class="toc-item"><li><span><a href="#THIS-IS-FROM-RAPIDAPI--->-https://rapidapi.com/community/api/open-weather-map/" data-toc-modified-id="THIS-IS-FROM-RAPIDAPI--->-https://rapidapi.com/community/api/open-weather-map/-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>THIS IS FROM RAPIDAPI --&gt; <a href="https://rapidapi.com/community/api/open-weather-map/" target="_blank">https://rapidapi.com/community/api/open-weather-map/</a></a></span></li><li><span><a href="#Insomnia" data-toc-modified-id="Insomnia-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Insomnia</a></span></li><li><span><a href="#Codes-generated-by-insomnia" data-toc-modified-id="Codes-generated-by-insomnia-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>Codes generated by insomnia</a></span></li></ul></li><li><span><a href="#Spotify" data-toc-modified-id="Spotify-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Spotify</a></span><ul class="toc-item"><li><span><a href="#Load-initial-credentials" data-toc-modified-id="Load-initial-credentials-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span>Load initial credentials</a></span></li><li><span><a href="#Get-token-from-those-initial-credentials" data-toc-modified-id="Get-token-from-those-initial-credentials-12.2"><span class="toc-item-num">12.2&nbsp;&nbsp;</span>Get token from those initial credentials</a></span></li><li><span><a href="#With-token,-we-can-create-the-headers" data-toc-modified-id="With-token,-we-can-create-the-headers-12.3"><span class="toc-item-num">12.3&nbsp;&nbsp;</span>With token, we can create the headers</a></span></li></ul></li><li><span><a href="#Summary" data-toc-modified-id="Summary-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Summary</a></span></li><li><span><a href="#Further-materials" data-toc-modified-id="Further-materials-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Further materials</a></span></li></ul></div>

# %% [markdown]
# ## Libraries summary

# %%
import pandas as pd
from pandas import json_normalize

import requests 
import json
import os
from dotenv import load_dotenv #conda install -c conda-forge python-dotenv

import time

import sys
sys.path.append("../")

# %% [markdown]
# ## Internet, DNS, IPs

# %% [markdown]
# ![enjuto](https://www.publico.es/files/article_main/uploads//2014/12/13/548bb18f1d9ef.jpg)

# %% [markdown]
# - DNS (Domain Name Server): Maps the Internet address www.google.com to the server IP: 216.58.222.196
# - IP: server identification. code that allows information to be sent and received by the correct parties
# - Domain providers: they sell and buy Internet domains

# %% [markdown]
# ## HTTP

# %% [markdown]
# **H**yper **T**ext **T**transfer **P**rotocolo
# HTTP is a communications protocol that provides a structure for requests between client and server on a network.
# For example, the web browser on the user's computer (the client) uses the HTTP protocol to request information from a website on a server.

# %% [markdown]
# ### URL
# Contains information about the resource that is being requested from the SERVER.
# Examples:
#
# - http://www.towardsdatascience.com
# - https://www.ironhack.com/
# - Protocol: https (https == http is the same but https is encrypted)
# - Domain name --> IRONHACK
# - TLD (top level domain) --> .com
# - https://www.google.com/webhp?authuser=2

# %%
#https://www.google.com/feelinglucky?q=b%C3%BAsqueda+random&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjVveXHkfD9AhUZVKQEHTYPCXMQ_AUoAXoECAIQAw&biw=1440&bih=765&dpr=2

# %% [markdown]
# ### HTTP vs HTTPS
#
# - HTTP transfers data in plain text while HTTPS transfers data in encrypted text.
# - HTTP is faster than HTTPS because the latter consumes computing power to encrypt the communication channel.

# %% [markdown]
# ### Requests

# %% [markdown]
# The **Requests** are questions that we ask a SERVER to receive information (a **response**).
# Types of request (verb):
# - GET: read the information from the resource, and do not modify it in any way. Accessing the web page from the browser **gets** information.
# - POST
# - PUT
# - DELETE
# - PATCH
# - ...

# %%
import requests
#requests.get("https://www.google.com").content

# %%
# JSON

# JavaScript Object Notation 

# Objeto en Javascript es un diccionario en python

# %% [markdown]
# ### Response
# Responses can be of various types:
# * a JSON (similar to Python's dictionary)
# * an image
# * a video
# * an HTML page
# * a PDF file
# * ...

# %% [markdown]
# The responses follow the following structure. Have:
# - a HEADER section: contains metadata about the behavior of the server
# - a BODY: contains the desired information
#
# An important part of the HEADER is the **status code**. This code is a numeric code indicating the result of the server. There are different status codes depending on whether the server has succeeded in making the request or has failed to do anything. Here are some groups of status codes:
#
# - **2xx** successful__: the request was received, understood and accepted successfully
# - **3xx** redirect__: more action is needed to complete the request
# - **4xx** client error__: request contains incorrect syntax or cannot be fulfilled
# - **5xx** server error__: the server was unable to complete an apparently valid request
#
# Complete list:
# https://en.wikipedia.org/wiki/List_of_HTTP_status_codes
#
# Much more fun:
# https://http.cat/

# %% [markdown]
# ## API

# %% [markdown]
# **A**pplication **P**rogramming **I**nterface
# - In the cloud era, programs need to communicate over the Internet.
# - Within a project, the backend may want to share information with the frontend without access to the database.
# - It is a contract between software products.
# * It is an instruction manual to use a software.
# * The client calls the server through an API, the server responds.

# %% [markdown]
# ![API - Waiter](https://miro.medium.com/max/1400/0*2tmGZJKP6LfDycgV.png)

# %% [markdown]
# ### RESTful APIs

# %% [markdown]
# Most interactive APIs follow REST logic, a set of rules
# - [REST Guiding Principles](https://restfulapi.net/)
#
# Who does what:
# - We (client) send a request
# - They (server) return a response, usually in JSON format
#
# APIs always have to offer documentation of their different services: **endpoints**<br>
# Each endpoint is a different URL

# %% [markdown]
# ## Let's go

# %% [markdown]
# ### Requests in Python

# %% [markdown]
# https://requests.readthedocs.io/en/master/

# %%
#!pip install requests
#conda install requests

# %%
import requests

# %%
response_pais = requests.get("https://elpais.com")

# %%
#response_pais.content

# %%
response_pais.headers
# Out:
# {'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '82192', 'Server': 'openresty', 'Content-Encoding': 'gzip', 'ETag': 'W/"643df-qZMaetH6wiUlBefPgn0l3SSsDcI"', 'Last-Modified': 'Wed, 22 Mar 2023 18:23:10 GMT', 'x-arc-pb-request-id': '850d23b3-c1cc-44b4-8849-52db5e1f6d1e', 'Vary': 'Accept-Encoding', 'Cache-Control': 'private, max-age=60', 'Expires': 'Wed, 22 Mar 2023 18:24:10 GMT', 'Date': 'Wed, 22 Mar 2023 18:23:10 GMT', 'Connection': 'keep-alive', 'Set-Cookie': 'arc-geo={"georegion":"200","countrycode":"ES","regioncode":"MD","timezone":"GMT+1","continent":"EU"}; expires=Wed, 22-Mar-2023 18:38:10 GMT; path=/, eptz=ES; path=/; domain=.elpais.com, hpage=1; expires=Thu, 21-Mar-2024 18:23:10 GMT; path=/; domain=.elpais.com', 'x-arc-request-id': '0.a66c1002.1679509390.221cf8f', 'Akamai-True-TTL': '130'}

# %% [markdown]
# ### HTML response

# %% [markdown]
# I can call a url and have all the html, all the response from the server.

# %% [markdown]
# ### JSON response

# %% [markdown]
# JSON: Java Script Object Notation

# %% [markdown]
# Let's get information from the ISS (international space station)

# %% [markdown]
# [ISS API documentation](https://wheretheiss.at/w/developer)

# %%
url = "https://api.wheretheiss.at/v1/satellites"

# %%
id_sat = requests.get(url).json()[0]["id"]
id_sat
# Out:
# 25544

# %% [markdown]
# If the Content-Type of the response is json, we can access it with `.json()`
# [Documentation](https://docs.python.org/3/library/json.html)

# %% [markdown]
# We make the call to the satellites endpoint with the id because it has already been returned to us by the previous request

# %%
url = f"https://api.wheretheiss.at/v1/satellites/{id_sat}"

# %%
res = requests.get(url).json()
res
# Out:
# {'name': 'iss',
#  'id': 25544,
#  'latitude': -49.428706597515,
#  'longitude': -174.37292783251,
#  'altitude': 438.27474712645,
#  'velocity': 27529.447022073,
#  'visibility': 'daylight',
#  'footprint': 4599.2925607811,
#  'timestamp': 1679509881,
#  'daynum': 2460026.2717708,
#  'solar_lat': 0.7467854730298,
#  'solar_lon': 263.88159329559,
#  'units': 'kilometers'}

# %% [markdown]
# ### Data management in pandas

# %%
import pandas as pd

# %%
df = pd.DataFrame([res])
df
# Out:
#   name     id   latitude   longitude    altitude      velocity visibility  \
# 0  iss  25544 -49.428707 -174.372928  438.274747  27529.447022   daylight
#
#      footprint   timestamp        daynum  solar_lat   solar_lon       units
# 0  4599.292561  1679509881  2.460026e+06   0.746785  263.881593  kilometers

# %%
df = pd.DataFrame.from_dict(res, orient = "index").T
df
# Out:
#   name     id   latitude   longitude    altitude      velocity visibility  \
# 0  iss  25544 -49.428707 -174.372928  438.274747  27529.447022   daylight
#
#      footprint   timestamp          daynum solar_lat   solar_lon       units
# 0  4599.292561  1679509881  2460026.271771  0.746785  263.881593  kilometers

# %%
import time
position = []

for i in range(10):
    time.sleep(2)
    res = requests.get(url).json()
    position.append(res)

# %%
df = pd.DataFrame(position)
df
# Out:
#   name     id   latitude   longitude    altitude      velocity visibility  \
# 0  iss  25544 -50.940826 -138.628060  439.812802  27524.444284   daylight
# 1  iss  25544 -50.916068 -138.436726  439.806468  27524.449964   daylight
# 2  iss  25544 -50.878294 -138.150132  439.796674  27524.459147   daylight
# 3  iss  25544 -50.839754 -137.864026  439.786530  27524.469124   daylight
# 4  iss  25544 -50.813637 -137.673559  439.779573  27524.476216   daylight
# 5  iss  25544 -50.773829 -137.388282  439.768846  27524.487515   daylight
# 6  iss  25544 -50.733263 -137.103515  439.757769  27524.499606   daylight
# 7  iss  25544 -50.705798 -136.913954  439.750191  27524.508106   daylight
# 8  iss  25544 -50.663973 -136.630052  439.738534  27524.521516   daylight
# 9  iss  25544 -50.635672 -136.441079  439.730570  27524.530895   daylight
#
#      footprint   timestamp        daynum  solar_lat   solar_lon       units
# 0  4606.919021  1679510250  2.460026e+06   0.748471  262.343774  kilometers
# 1  4606.887644  1679510252  2.460026e+06   0.748480  262.335439  kilometers
# 2  4606.839131  1679510255  2.460026e+06   0.748494  262.322936  kilometers
# 3  4606.788882  1679510258  2.460026e+06   0.748507  262.310434  kilometers
# 4  4606.754417  1679510260  2.460026e+06   0.748517  262.302099  kilometers
# 5  4606.701278  1679510263  2.460026e+06   0.748530  262.289596  kilometers
# 6  4606.646409  1679510266  2.460026e+06   0.748544  262.277094  kilometers
# 7  4606.608868  1679510268  2.460026e+06   0.748553  262.268758  kilometers
# 8  4606.551121  1679510271  2.460026e+06   0.748567  262.256256  kilometers
# 9  4606.511666  1679510273  2.460026e+06   0.748576  262.247921  kilometers

# %% [markdown]
# ### Parameters

# %% [markdown]
# Remember... The API Documentation
# https://wheretheiss.at/w/developer

# %% [markdown]
# ![captura](../../images/parameters.png)

# %% [markdown]
# Sometimes we want to pass some parameters to an API endpoint.
# Similar to python functions receiving parameters for different behavior

# %% [markdown]
# Parameters are passed with `?param1=value1&param2=value2...` at the end of the URL

# %%
#https//wwww.gogole.com/search?jkdnfjdfjd
url = f"https://api.wheretheiss.at/v1/satellites/{id_sat}?units=miles"

# %%
requests.get(url).json()
# Out:
# {'name': 'iss',
#  'id': 25544,
#  'latitude': -46.825681937028,
#  'longitude': -120.61527893582,
#  'altitude': 272.41467984352,
#  'velocity': 17104.337712275,
#  'visibility': 'daylight',
#  'footprint': 2858.2812493513,
#  'timestamp': 1679510453,
#  'daynum': 2460026.2783912,
#  'solar_lat': 0.74939815103938,
#  'solar_lon': 261.49776488914,
#  'units': 'miles'}

# %% [markdown]
# The `requests` library lets pass the parameters as a dictionary

# %%
url = f"https://api.wheretheiss.at/v1/satellites/{id_sat}"
my_params = {"units":"miles"}
requests.get(url, params=my_params).json()
# Out:
# {'name': 'iss',
#  'id': 25544,
#  'latitude': -42.487539272471,
#  'longitude': -110.30694133986,
#  'altitude': 271.33781248927,
#  'velocity': 17106.480837304,
#  'visibility': 'daylight',
#  'footprint': 2852.9309562872,
#  'timestamp': 1679510591,
#  'daynum': 2460026.2799884,
#  'solar_lat': 0.75002847963778,
#  'solar_lon': 260.92264554286,
#  'units': 'miles'}

# %% [markdown]
# ### Mini-recap
#
# - APIS: aplicaciones que otra persona construye
# - Nos dan informacion
# - Acatar sus reglas
# - DOCUMENTACIÓN!
# - Nos devuelven JSONS
#
# - Podemos parametrizar: la URL ó un diccionario con parámetros
# - Requests: a websites normales (google.com) ó a APIs (aapi.whereistheiss.com)

# %% [markdown]
# ## It's now your turn

# %% [markdown]
# Check out this API... 👆or any other, [YOU CAN LOOK HERE](https://github.com/public-apis/public-apis) to do the exercise.
# Try to call an API, with or without parameters and... get some information!!

# %%
# Kanye rest

requests.get("https://api.kanye.rest").json()
# Out:
# {'quote': 'Man... whatever happened to my antique fish tank?'}

# %% [markdown]
# ```bash
# $ curl -H "Accept: application/json" https://icanhazdadjoke.com/
# {
#   "id": "R7UfaahVfFd",
#   "joke": "My dog used to chase people on a bike a lot. It got so bad I had to take his bike away.",
#   "status": 200
# }
# ```

# %%
# dad jokes

headers = {"Accept": "application/json"}
requests.get("https://icanhazdadjoke.com/", headers=headers).json()
# Out:
# {'id': 'usrcaMuszd',
#  'joke': "What's the worst thing about ancient history class? The teachers tend to Babylon.",
#  'status': 200}

# %%
# Kevin 

url= "https://api.domainsdb.info/v1"
API= requests.get(url)

domain= "cat"
limit= "limit=20"
req= requests.get(url + "/domains/search?" + limit + "&domain=" + domain)

df = pd.DataFrame(req.json())
df.head(5)

domains= df.domains.head(5)

domains
# Out:
# 0    {'domain': 'vjfqbstulrbmp0n7f5vigo021kp84d28.c...
# 1    {'domain': 'vhpjdfktfb5vt63r0cqu71ldj8cei567.c...
# 2    {'domain': 'tg1nig1dm2hl6lrb7kglj0lgfqej2eo9.c...
# 3    {'domain': 'tn3q9pmjh3b7n6hcuee3pcqg88hhvpc0.c...
# 4    {'domain': 't3ronl9nv866nnsdmsfbd2a9hn681m56.c...
# Name: domains, dtype: object

# %%
domains[4]
# Out:
# {'domain': 't3ronl9nv866nnsdmsfbd2a9hn681m56.cat',
#  'create_date': '2023-03-22T05:37:11.278612',
#  'update_date': '2023-03-22T05:37:11.278614',
#  'country': None,
#  'isDead': 'False',
#  'A': None,
#  'NS': None,
#  'CNAME': None,
#  'MX': None,
#  'TXT': None}

# %%
# cat - facts


url_base = "https://cat-fact.herokuapp.com/facts"

requests.get(url_base).json()[0]["text"]
# Out:
# 'Cats make about 100 different sounds. Dogs make only about 10.'

# %%
# AUGUSTO
from PIL import Image
import requests
from io import BytesIO

response = requests.get("https://qrtag.net/api/qr_4.png?url=https://www.google.es")
img = Image.open(BytesIO(response.content))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=124x124 at 0x7FC069E59820>

# %%
# Mariano
url = 'https://tenders.guru/api/es/tenders'
req = requests.get(url)
data = req.json()
df = pd.DataFrame(data)
df
# Out:
#     page_count  page_number  page_size   total  \
# 0         7146            1        100  714598
# 1         7146            1        100  714598
# 2         7146            1        100  714598
# 3         7146            1        100  714598
# 4         7146            1        100  714598
# ..         ...          ...        ...     ...
# 95        7146            1        100  714598
# 96        7146            1        100  714598
# 97        7146            1        100  714598
# 98        7146            1        100  714598
# 99        7146            1        100  714598
#
#                                                  data
# 0   {'id': '831333', 'date': '2021-06-29', 'deadli...
# 1   {'id': '831322', 'date': '2021-05-17', 'deadli...
# 2   {'id': '831319', 'date': '2021-06-29', 'title'...
# 3   {'id': '831318', 'date': '2021-06-29', 'title'...
# 4   {'id': '831317', 'date': '2021-05-26', 'deadli...
# ..                                                ...
# 95  {'id': '830910', 'date': '2021-06-28', 'deadli...
# 96  {'id': '830897', 'date': '2021-06-28', 'deadli...
# 97  {'id': '830884', 'date': '2021-05-04', 'deadli...
# 98  {'id': '830883', 'date': '2021-06-09', 'deadli...
# 99  {'id': '830875', 'date': '2021-06-02', 'deadli...
#
# [100 rows x 5 columns]

# %%
# Xavi

country_code = "ES"
url = f"https://api.openaq.org/v2/locations?country={country_code}"
headers = {"Accept": "application/json"}
response = requests.get(url, headers=headers).json()
df = pd.DataFrame(response["results"])
df
# Out:
#         id           city                                               name  \
# 0   281864        Almeria                      C. Restoy, 51, Almeria, Spain
# 1   276005           None                                  Starlab Barcelona
# 2   278343           None                                      Calle Azafran
# 3    66625           None  Elx Carrus http://www.meteoelx.com Calidad del...
# 4   270207           None                                  JJ5-Arco Ladrillo
# ..     ...            ...                                                ...
# 95    3268      Tarragona                                            ES1812A
# 96    3269      Barcelona                                            ES1551A
# 97    3270  Illes Balears                                            ES0006R
# 98    3271      Tarragona                                            ES1379A
# 99    3272    Guadalajara                                            ES0009R
#
#         entity country                                            sources  \
# 0         None      ES  [{'url': None, 'name': 'senstate', 'id': 'sens...
# 1    community      ES  [{'url': 'https://www2.purpleair.com/', 'name'...
# 2    community      ES  [{'url': 'https://www2.purpleair.com/', 'name'...
# 3    community      ES  [{'url': 'https://www2.purpleair.com/', 'name'...
# 4    community      ES  [{'url': 'https://www2.purpleair.com/', 'name'...
# ..         ...     ...                                                ...
# 95  government      ES  [{'url': 'http://www.eea.europa.eu/themes/air/...
# 96  government      ES  [{'url': 'http://www.eea.europa.eu/themes/air/...
# 97  government      ES  [{'url': 'http://www.eea.europa.eu/themes/air/...
# 98  government      ES  [{'url': 'http://www.eea.europa.eu/themes/air/...
# 99  government      ES  [{'url': 'http://www.eea.europa.eu/themes/air/...
#
#     isMobile isAnalysis                                         parameters  \
# 0      False       None  [{'id': 2089695, 'unit': 'µg/m³', 'count': 757...
# 1      False       None  [{'id': 1575276, 'unit': 'particles/cm³', 'cou...
# 2      False       None  [{'id': 1583989, 'unit': 'µg/m³', 'count': 415...
# 3      False      False  [{'id': 405164, 'unit': 'µg/m³', 'count': 1183...
# 4      False       None  [{'id': 1559657, 'unit': 'particles/cm³', 'cou...
# ..       ...        ...                                                ...
# 95     False      False  [{'id': 7112, 'unit': 'µg/m³', 'count': 60279,...
# 96     False      False  [{'id': 7111, 'unit': 'µg/m³', 'count': 60256,...
# 97     False      False  [{'id': 7116, 'unit': 'µg/m³', 'count': 64831,...
# 98     False      False  [{'id': 7114, 'unit': 'µg/m³', 'count': 61117,...
# 99     False      False  [{'id': 7117, 'unit': 'µg/m³', 'count': 57381,...
#
#          sensorType                                        coordinates  \
# 0   low-cost sensor        {'latitude': 36.8466, 'longitude': -2.4649}
# 1   low-cost sensor     {'latitude': 41.415127, 'longitude': 2.131705}
# 2   low-cost sensor     {'latitude': 41.66933, 'longitude': -4.729943}
# 3   low-cost sensor     {'latitude': 38.276432, 'longitude': -0.71009}
# 4   low-cost sensor     {'latitude': 41.64335, 'longitude': -4.731341}
# ..              ...                                                ...
# 95  reference grade  {'latitude': 41.2783810944675, 'longitude': 1....
# 96  reference grade  {'latitude': 41.512675807467, 'longitude': 2.1...
# 97  reference grade  {'latitude': 39.8752799994714, 'longitude': 4....
# 98  reference grade  {'latitude': 41.058203797468, 'longitude': 0.4...
# 99  reference grade  {'latitude': 41.2741699994675, 'longitude': -3...
#
#                   lastUpdated               firstUpdated  measurements bounds  \
# 0   2023-03-22T19:00:00+00:00  2022-02-09T08:32:00+00:00       3043314   None
# 1   2023-03-22T18:59:40+00:00  2022-01-20T16:32:10+00:00       3334734   None
# 2   2023-03-22T18:59:34+00:00  2022-01-29T18:35:17+00:00       2490498   None
# 3   2023-03-22T18:59:32+00:00  2021-01-20T00:00:00+00:00       7098732   None
# 4   2023-03-22T18:59:30+00:00  2021-10-19T10:17:21+00:00       2305638   None
# ..                        ...                        ...           ...    ...
# 95  2023-03-22T16:00:00+00:00  2016-11-17T23:00:00+00:00        211403   None
# 96  2023-03-22T16:00:00+00:00  2016-11-17T23:00:00+00:00         60256   None
# 97  2023-03-22T16:00:00+00:00  2016-11-17T23:00:00+00:00        193105   None
# 98  2023-03-22T16:00:00+00:00  2016-11-17T23:00:00+00:00         61117   None
# 99  2023-03-22T16:00:00+00:00  2016-11-17T23:00:00+00:00        170846   None
#
#    manufacturers
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
# ..           ...
# 95          None
# 96          None
# 97          None
# 98          None
# 99          None
#
# [100 rows x 16 columns]

# %%
# Mariano
url2 = 'https://api.coinstats.app/public/v1/coins?skip=0&limit=10&currency=USD'
req = requests.get(url2)
df = pd.DataFrame(req.json()['coins'])
df
# Out:
#               id                                               icon  \
# 0        bitcoin  https://static.coinstats.app/coins/16504555888...
# 1       ethereum  https://static.coinstats.app/coins/16504556297...
# 2         tether  https://static.coinstats.app/coins/16504557718...
# 3   binance-coin  https://static.coinstats.app/coins/16666081453...
# 4       usd-coin  https://static.coinstats.app/coins/16504558250...
# 5         ripple    https://static.coinstats.app/coins/XRPdnqGJ.png
# 6        cardano  https://static.coinstats.app/coins/CardanojXdd...
# 7   staked-ether  https://static.coinstats.app/coins/staked-ethe...
# 8       dogecoin  https://static.coinstats.app/coins/DogecoinIZa...
# 9  matic-network  https://static.coinstats.app/coins/16605770115...
#
#                 name symbol  rank         price  priceBtc        volume  \
# 0            Bitcoin    BTC     1  27493.037515  1.000000  5.256258e+10
# 1           Ethereum    ETH     2   1751.142754  0.063728  1.542554e+11
# 2             Tether   USDT     3      1.007650  0.000037  2.743561e+11
# 3                BNB    BNB     4    323.195252  0.011762  2.216871e+09
# 4           USD Coin   USDC     5      1.004000  0.000036  5.429402e+09
# 5                XRP    XRP     6      0.425246  0.000015  7.547069e+09
# 6            Cardano    ADA     7      0.361382  0.000013  1.714436e+09
# 7  Lido Staked Ether  STETH     8   1753.840000  0.063531  3.339020e+07
# 8           Dogecoin   DOGE     9      0.073666  0.000003  1.422243e+09
# 9            Polygon  MATIC    10      1.115356  0.000041  1.180056e+09
#
#       marketCap  availableSupply  totalSupply  priceChange1h  priceChange1d  \
# 0  5.313040e+11         19325037     21000000          -3.50          -2.37
# 1  2.109313e+11        120453489    120453489          -2.08          -2.65
# 2  7.802876e+10      77436340550  77436340550           0.04           0.19
# 3  5.103099e+10        157895234    157900174          -1.44          -4.48
# 4  3.511852e+10      34915608756  34915637756          -0.16           0.06
# 5  2.166670e+10      50950912949  99989113908          -3.21          -8.21
# 6  1.266464e+10      35045020830  45000000000          -3.89          -0.48
# 7  1.029944e+10          5843773      5843773          -2.28          -2.59
# 8  1.021215e+10     138627966384            0          -3.33          -2.38
# 9  1.012796e+10       9080469069  10000000000          -2.00          -2.24
#
#    priceChange1w                        websiteUrl  \
# 0          12.65            http://www.bitcoin.org
# 1           6.43         https://www.ethereum.org/
# 2           0.16                https://tether.to/
# 3           5.77          https://www.binance.com/
# 4           0.32    https://www.circle.com/en/usdc
# 5          17.24      https://ripple.com/currency/
# 6          10.64  https://www.cardano.org/en/home/
# 7           3.17               https://www.lido.fi
# 8           6.47              http://dogecoin.com/
# 9          -0.03       https://polygon.technology/
#
#                         twitterUrl  \
# 0      https://twitter.com/bitcoin
# 1     https://twitter.com/ethereum
# 2    https://twitter.com/Tether_to
# 3      https://twitter.com/binance
# 4    https://twitter.com/circlepay
# 5       https://twitter.com/Ripple
# 6   https://twitter.com/Cardano_CF
# 7  https://twitter.com/lidofinance
# 8     https://twitter.com/dogecoin
# 9    https://twitter.com/0xPolygon
#
#                                                  exp  \
# 0  [https://blockchair.com/bitcoin/, https://btc....
# 1  [https://etherscan.io/, https://ethplorer.io/,...
# 2  [https://etherscan.io/token/0xdac17f958d2ee523...
# 3  [https://bscscan.com, https://explorer.binance...
# 4  [https://etherscan.io/token/0xa0b86991c6218b36...
# 5  [https://blockchair.com/ripple, https://xrpcha...
# 6  [https://cardanoscan.io/, https://cardanoexplo...
# 7  [https://etherscan.io/token/0xae7ab96520de3a18...
# 8  [https://blockchair.com/dogecoin, https://doge...
# 9  [https://etherscan.io/token/0x7d1afa7b718fb893...
#
#                               contractAddress  decimals  \
# 0                                         NaN       NaN
# 1  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2      18.0
# 2  0xdac17f958d2ee523a2206206994597c13d831ec7      18.0
# 3                                         BNB      18.0
# 4  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48      18.0
# 5  0x1d2f0da169ceb9fc7b3144628db156f3f6c60dbe      18.0
# 6  0x3ee2200efb3400fabb9aacf31297cbdd1d435d47      18.0
# 7  0xae7ab96520de3a18e5e111b5eaab095312d7fe84      18.0
# 8  0xba2ae424d960c26247dd6c32edc70b295c744c43      18.0
# 9  0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0      18.0
#
#                            redditUrl
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8  https://www.reddit.com/r/dogecoin
# 9                                NaN

# %% [markdown]
# ![Screenshot%202022-10-20%20at%2014.06.06.png](attachment:Screenshot%202022-10-20%20at%2014.06.06.png)

# %% [markdown]
# ## STEPS TO GET REPONSES
#
# 1. Look for an API if it exists
# 2. Read the docs that that person created
# 3. I get the URL for the API: different from website url, "api.something"
# 4. I can issue requests through Python to the API-url
#
#
# ## STEPS TO MANIPULATE THE RESPONSES
#
# 1. If request object -> pass res.json() _probably_
# 2. I have a dictionary -> Do I want to turn it into a df?
# 3. You MIGHT want to do `json_normalize(res.json())`

# %% [markdown]
# ## Headers

# %% [markdown]
# HTTP headers are an important part of the API request and response, as they represent the metadata associated with the API request and response. Headers carry information for:
#
# - Request and response body
# - Authorization of the request
# - Cache of the response
# - Response cookies

# %% [markdown]
# ## API Keys / tokens / private_keys
# Some of the APIs we use will require authentication.

# %% [markdown]
# - https://github.com/settings/tokens
# - https://docs.github.com/es/rest/guides/getting-started-with-the-rest-api
# - https://pypi.org/project/python-dotenv/
# - https://docs.github.com/es/rest/reference/permissions-required-for-github-apps

# %%
.gitignore
    .DS_Store
    .ipynb_checkpoints
    dataset/sharks
    .env

.env #guardar variables de entorno

# %%
import os
import requests
from dotenv import load_dotenv 
load_dotenv()
# Out:
# True

# %%
sql_password = os.getenv("sql_password")

# %%
# 1. Creo el gitignore
# 2. Añadio el .env
# 3. Creo el .env
# 4. Meto las credenciales en el .env

# %%
password="password"

# %%
#gh_token

# %%
# 1. Create .env
# 2. Include .env in our .gitignore
# 3. Include environment variables into .env
# 4. Import environment variables into notebooks
# 5. DO NOT INCLUDE PRINTS OF THE VARIABLES ON YOUR NOTEBOOKS

# %%
# github.com -> link to website
# api.github.com -> link to api

# %% [markdown]
# Philosophy of life : What I do for one element of the list I do for all of them in one iteration, so let's review the first element and then we'll see

# %% [markdown]
# `.env`

# %%
url_repo = "https://github.com/public-apis/public-apis"

# %%
gh_token = os.getenv("github_token")

# %%
user = "public-apis"

# %%
repo = "public-apis"

# %%
url_base = f"https://api.github.com/repos/{user}/{repo}/forks"

# %%
url_base
# Out:
# 'https://api.github.com/repos/public-apis/public-apis/forks'

# %%
params = {"Authentication": f"token {gh_token}"}

# %%
response = requests.get(url_base, params=params).json()
response
# Out:
# [{'id': 617620885,
#   'node_id': 'R_kgDOJNAllQ',
#   'name': 'public-apis',
#   'full_name': 'Xavi1250/public-apis',
#   'private': False,
#   'owner': {'login': 'Xavi1250',
#    'id': 119597527,
#    'node_id': 'U_kgDOByDp1w',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/119597527?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Xavi1250',
#    'html_url': 'https://github.com/Xavi1250',
#    'followers_url': 'https://api.github.com/users/Xavi1250/followers',
#    'following_url': 'https://api.github.com/users/Xavi1250/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Xavi1250/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Xavi1250/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Xavi1250/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Xavi1250/orgs',
#    'repos_url': 'https://api.github.com/users/Xavi1250/repos',
#    'events_url': 'https://api.github.com/users/Xavi1250/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Xavi1250/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Xavi1250/public-apis',
#   'description': 'A collective list of free APIs',
#   'fork': True,
#   'url': 'https://api.github.com/repos/Xavi1250/public-apis',
#   'forks_url': 'https://api.github.com/repos/Xavi1250/public-apis/forks',
#   'keys_url': 'https://api.github.com/repos/Xavi1250/public-apis/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Xavi1250/public-apis/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Xavi1250/public-apis/teams',
#   'hooks_url': 'https://api.github.com/repos/Xavi1250/public-apis/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Xavi1250/public-apis/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Xavi1250/public-apis/events',
#   'assignees_url': 'https://api.github.com/repos/Xavi1250/public-apis/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Xavi1250/public-apis/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Xavi1250/public-apis/tags',
#   'blobs_url': 'https://api.github.com/repos/Xavi1250/public-apis/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Xavi1250/public-apis/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Xavi1250/public-apis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Xavi1250/public-apis/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Xavi1250/public-apis/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Xavi1250/public-apis/languages',
#   'stargazers_url': 'https://api.github.com/repos/Xavi1250/public-apis/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Xavi1250/public-apis/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Xavi1250/public-apis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Xavi1250/public-apis/subscription',
#   'commits_url': 'https://api.github.com/repos/Xavi1250/public-apis/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Xavi1250/public-apis/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Xavi1250/public-apis/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Xavi1250/public-apis/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Xavi1250/public-apis/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Xavi1250/public-apis/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Xavi1250/public-apis/merges',
#   'archive_url': 'https://api.github.com/repos/Xavi1250/public-apis/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Xavi1250/public-apis/downloads',
#   'issues_url': 'https://api.github.com/repos/Xavi1250/public-apis/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Xavi1250/public-apis/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Xavi1250/public-apis/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Xavi1250/public-apis/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Xavi1250/public-apis/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Xavi1250/public-apis/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Xavi1250/public-apis/deployments',
#   'created_at': '2023-03-22T19:07:13Z',
#   'updated_at': '2023-03-22T18:56:59Z',
#   'pushed_at': '2023-03-22T13:23:23Z',
#   'git_url': 'git://github.com/Xavi1250/public-apis.git',
#   'ssh_url': 'git@github.com:Xavi1250/public-apis.git',
#   'clone_url': 'https://github.com/Xavi1250/public-apis.git',
#   'svn_url': 'https://github.com/Xavi1250/public-apis',
#   'homepage': 'http://public-apis.org',
#   'size': 4948,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 617573550,
#   'node_id': 'R_kgDOJM9srg',
#   'name': 'public-apis',
#   'full_name': 'stavares843/public-apis',
#   'private': False,
#   'owner': {'login': 'stavares843',
#    'id': 29093946,
#    'node_id': 'MDQ6VXNlcjI5MDkzOTQ2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29093946?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stavares843',
#    'html_url': 'https://github.com/stavares843',
#    'followers_url': 'https://api.github.com/users/stavares843/followers',
#    'following_url': 'https://api.github.com/users/stavares843/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/stavares843/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/stavares843/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/stavares843/subscriptions',
#    'organizations_url': 'https://api.github.com/users/stavares843/orgs',
#    'repos_url': 'https://api.github.com/users/stavares843/repos',
#    'events_url': 'https://api.github.com/users/stavares843/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/stavares843/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/stavares843/public-apis',
#   'description': 'A collective list of free APIs',
#   'fork': True,
#   'url': 'https://api.github.com/repos/stavares843/public-apis',
#   'forks_url': 'https://api.github.com/repos/stavares843/public-apis/forks',
#   'keys_url': 'https://api.github.com/repos/stavares843/public-apis/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/stavares843/public-apis/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/stavares843/public-apis/teams',
#   'hooks_url': 'https://api.github.com/repos/stavares843/public-apis/hooks',
#   'issue_events_url': 'https://api.github.com/repos/stavares843/public-apis/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/stavares843/public-apis/events',
#   'assignees_url': 'https://api.github.com/repos/stavares843/public-apis/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/stavares843/public-apis/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/stavares843/public-apis/tags',
#   'blobs_url': 'https://api.github.com/repos/stavares843/public-apis/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/stavares843/public-apis/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/stavares843/public-apis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/stavares843/public-apis/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/stavares843/public-apis/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/stavares843/public-apis/languages',
#   'stargazers_url': 'https://api.github.com/repos/stavares843/public-apis/stargazers',
#   'contributors_url': 'https://api.github.com/repos/stavares843/public-apis/contributors',
#   'subscribers_url': 'https://api.github.com/repos/stavares843/public-apis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/stavares843/public-apis/subscription',
#   'commits_url': 'https://api.github.com/repos/stavares843/public-apis/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/stavares843/public-apis/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/stavares843/public-apis/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/stavares843/public-apis/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/stavares843/public-apis/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/stavares843/public-apis/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/stavares843/public-apis/merges',
#   'archive_url': 'https://api.github.com/repos/stavares843/public-apis/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/stavares843/public-apis/downloads',
#   'issues_url': 'https://api.github.com/repos/stavares843/public-apis/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/stavares843/public-apis/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/stavares843/public-apis/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/stavares843/public-apis/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/stavares843/public-apis/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/stavares843/public-apis/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/stavares843/public-apis/deployments',
#   'created_at': '2023-03-22T17:05:29Z',
#   'updated_at': '2023-03-22T16:54:39Z',
#   'pushed_at': '2023-03-22T13:23:23Z',
#   'git_url': 'git://github.com/stavares843/public-apis.git',
#   'ssh_url': 'git@github.com:stavares843/public-apis.git',
#   'clone_url': 'https://github.com/stavares843/public-apis.git',
#   'svn_url': 'https://github.com/stavares843/public-apis',
#   'homepage': 'http://public-apis.org',
#   'size': 4948,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 617554069,
#   'node_id': 'R_kgDOJM8glQ',
#   'name': '999-public-apis',
#   'full_name': 'Maoshanwen/999-public-apis',
#   'private': False,
#   'owner': {'login': 'Maoshanwen',
#    'id': 80189087,
#    'node_id': 'MDQ6VXNlcjgwMTg5MDg3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80189087?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Maoshanwen',
#    'html_url': 'https://github.com/Maoshanwen',
#    'followers_url': 'https://api.github.com/users/Maoshanwen/followers',
#    'following_url': 'https://api.github.com/users/Maoshanwen/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Maoshanwen/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Maoshanwen/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Maoshanwen/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Maoshanwen/orgs',
#    'repos_url': 'https://api.github.com/users/Maoshanwen/repos',
#    'events_url': 'https://api.github.com/users/Maoshanwen/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Maoshanwen/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Maoshanwen/999-public-apis',
#   'description': 'A collective list of free APIs',
#   'fork': True,
#   'url': 'https://api.github.com/repos/Maoshanwen/999-public-apis',
#   'forks_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/forks',
#   'keys_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/teams',
#   'hooks_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/events',
#   'assignees_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/tags',
#   'blobs_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/languages',
#   'stargazers_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/subscription',
#   'commits_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/merges',
#   'archive_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/downloads',
#   'issues_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Maoshanwen/999-public-apis/deployments',
#   'created_at': '2023-03-22T16:18:01Z',
#   'updated_at': '2023-03-22T16:05:08Z',
#   'pushed_at': '2023-03-22T13:23:23Z',
#   'git_url': 'git://github.com/Maoshanwen/999-public-apis.git',
#   'ssh_url': 'git@github.com:Maoshanwen/999-public-apis.git',
#   'clone_url': 'https://github.com/Maoshanwen/999-public-apis.git',
#   'svn_url': 'https://github.com/Maoshanwen/999-public-apis',
#   'homepage': 'http://public-apis.org',
#   'size': 4948,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 617462013,
#   'node_id': 'R_kgDOJM24_Q',
#   'name': 'public-apis',
#   'full_name': 'Psycoguana/public-apis',
#   'private': False,
#   'owner': {'login': 'Psycoguana',
#    'id': 21992381,
#    'node_id': 'MDQ6VXNlcjIxOTkyMzgx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21992381?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Psycoguana',
#    'html_url': 'https://github.com/Psycoguana',
#    'followers_url': 'https://api.github.com/users/Psycoguana/followers',
#    'following_url': 'https://api.github.com/users/Psycoguana/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Psycoguana/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Psycoguana/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Psycoguana/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Psycoguana/orgs',
#    'repos_url': 'https://api.github.com/users/Psycoguana/repos',
#    'events_url': 'https://api.github.com/users/Psycoguana/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Psycoguana/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Psycoguana/public-apis',
#   'description': 'A collective list of free APIs',
#   'fork': True,
#   'url': 'https://api.github.com/repos/Psycoguana/public-apis',
#   'forks_url': 'https://api.github.com/repos/Psycoguana/public-apis/forks',
#   'keys_url': 'https://api.github.com/repos/Psycoguana/public-apis/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Psycoguana/public-apis/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Psycoguana/public-apis/teams',
#   'hooks_url': 'https://api.github.com/repos/Psycoguana/public-apis/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Psycoguana/public-apis/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Psycoguana/public-apis/events',
#   'assignees_url': 'https://api.github.com/repos/Psycoguana/public-apis/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Psycoguana/public-apis/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Psycoguana/public-apis/tags',
#   'blobs_url': 'https://api.github.com/repos/Psycoguana/public-apis/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Psycoguana/public-apis/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Psycoguana/public-apis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Psycoguana/public-apis/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Psycoguana/public-apis/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Psycoguana/public-apis/languages',
#   'stargazers_url': 'https://api.github.com/repos/Psycoguana/public-apis/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Psycoguana/public-apis/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Psycoguana/public-apis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Psycoguana/public-apis/subscription',
#   'commits_url': 'https://api.github.com/repos/Psycoguana/public-apis/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Psycoguana/public-apis/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Psycoguana/public-apis/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Psycoguana/public-apis/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Psycoguana/public-apis/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Psycoguana/public-apis/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Psycoguana/public-apis/merges',
#   'archive_url': 'https://api.github.com/repos/Psycoguana/public-apis/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Psycoguana/public-apis/downloads',
#   'issues_url': 'https://api.github.com/repos/Psycoguana/public-apis/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Psycoguana/public-apis/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Psycoguana/public-apis/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Psycoguana/public-apis/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Psycoguana/public-apis/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Psycoguana/public-apis/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Psycoguana/public-apis/deployments',
#   'created_at': '2023-03-22T12:53:48Z',
#   'updated_at': '2023-03-22T12:45:19Z',
#   'pushed_at': '2023-03-22T13:20:46Z',
#   'git_url': 'git://github.com/Psycoguana/public-apis.git',
#   'ssh_url': 'git@github.com:Psycoguana/public-apis.git',
#   'clone_url': 'https://github.com/Psycoguana/public-apis.git',
#   'svn_url': 'https://github.com/Psycoguana/public-apis',
#   'homepage': 'http://public-apis.org',
#   'size': 4954,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 617436610,
#   'node_id': 'R_kgDOJM1Vwg',
#   'name': 'public-apis',
#   'full_name': 'PetrVakulenko/public-apis',
#   'private': False,
#   'owner': {'login': 'PetrVakulenko',
#    'id': 24455335,
#    'node_id': 'MDQ6VXNlcjI0NDU1MzM1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24455335?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PetrVakulenko',
#    'html_url': 'https://github.com/PetrVakulenko',
#    'followers_url': 'https://api.github.com/users/PetrVakulenko/followers',
#    'following_url': 'https://api.github.com/users/PetrVakulenko/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/PetrVakulenko/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/PetrVakulenko/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/PetrVakulenko/subscriptions',
#    'organizations_url': 'https://api.github.com/users/PetrVakulenko/orgs',
#    'repos_url': 'https://api.github.com/users/PetrVakulenko/repos',
#    'events_url': 'https://api.github.com/users/PetrVakulenko/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/PetrVakulenko/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/PetrVakulenko/public-apis',
#   'description': 'A collective list of free APIs',
#   'fork': True,
#   'url': 'https://api.github.com/repos/PetrVakulenko/public-apis',
#   'forks_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/forks',
#   'keys_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/teams',
#   'hooks_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/hooks',
#   'issue_events_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/events',
#   'assignees_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/tags',
#   'blobs_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/languages',
#   'stargazers_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/stargazers',
#   'contributors_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/contributors',
#   'subscribers_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/subscription',
#   'commits_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/merges',
#   'archive_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/downloads',
#   'issues_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/PetrVakulenko/public-apis/deployments',
#   'created_at': '2023-03-22T11:48:49Z',
#   'updated_at': '2023-03-22T12:21:59Z',
#   'pushed_at': '2023-03-22T12:30:32Z',
#   'git_url': 'git://github.com/PetrVakulenko/public-apis.git',
#   'ssh_url': 'git@github.com:PetrVakulenko/public-apis.git',
#   'clone_url': 'https://github.com/PetrVakulenko/public-apis.git',
#   'svn_url': 'https://github.com/PetrVakulenko/public-apis',
#   'homepage': 'http://public-apis.org',
#   'size': 4955,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 617317994,
#   'node_id': 'R_kgDOJMuGag',
#   'name': 'public-apis',
#   'full_name': '0xbadidea/public-apis',
#   'private': False,
#   'owner': {'login': '0xbadidea',
#    'id': 89309725,
#    'node_id': 'MDQ6VXNlcjg5MzA5NzI1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89309725?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/0xbadidea',
#    'html_url': 'https://github.com/0xbadidea',
#    'followers_url': 'https://api.github.com/users/0xbadidea/followers',
#    'following_url': 'https://api.github.com/users/0xbadidea/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/0xbadidea/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/0xbadidea/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/0xbadidea/subscriptions',
#    'organizations_url': 'https://api.github.com/users/0xbadidea/orgs',
#    'repos_url': 'https://api.github.com/users/0xbadidea/repos',
#    'events_url': 'https://api.github.com/users/0xbadidea/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/0xbadidea/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/0xbadidea/public-apis',
#   'description': 'A collective list of free APIs',
#   'fork': True,
#   'url': 'https://api.github.com/repos/0xbadidea/public-apis',
#   'forks_url': 'https://api.github.com/repos/0xbadidea/public-apis/forks',
#   'keys_url': 'https://api.github.com/repos/0xbadidea/public-apis/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/0xbadidea/public-apis/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/0xbadidea/public-apis/teams',
#   'hooks_url': 'https://api.github.com/repos/0xbadidea/public-apis/hooks',
#   'issue_events_url': 'https://api.github.com/repos/0xbadidea/public-apis/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/0xbadidea/public-apis/events',
#   'assignees_url': 'https://api.github.com/repos/0xbadidea/public-apis/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/0xbadidea/public-apis/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/0xbadidea/public-apis/tags',
#   'blobs_url': 'https://api.github.com/repos/0xbadidea/public-apis/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/0xbadidea/public-apis/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/0xbadidea/public-apis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/0xbadidea/public-apis/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/0xbadidea/public-apis/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/0xbadidea/public-apis/languages',
#   'stargazers_url': 'https://api.github.com/repos/0xbadidea/public-apis/stargazers',
#   'contributors_url': 'https://api.github.com/repos/0xbadidea/public-apis/contributors',
#   'subscribers_url': 'https://api.github.com/repos/0xbadidea/public-apis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/0xbadidea/public-apis/subscription',
#   'commits_url': 'https://api.github.com/repos/0xbadidea/public-apis/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/0xbadidea/public-apis/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/0xbadidea/public-apis/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/0xbadidea/public-apis/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/0xbadidea/public-apis/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/0xbadidea/public-apis/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/0xbadidea/public-apis/merges',
#   'archive_url': 'https://api.github.com/repos/0xbadidea/public-apis/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/0xbadidea/public-apis/downloads',
#   'issues_url': 'https://api.github.com/repos/0xbadidea/public-apis/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/0xbadidea/public-apis/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/0xbadidea/public-apis/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/0xbadidea/public-apis/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/0xbadidea/public-apis/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/0xbadidea/public-apis/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/0xbadidea/public-apis/deployments',
#   'created_at': '2023-03-22T06:15:40Z',
#   'updated_at': '2023-03-22T06:14:31Z',
#   'pushed_at': '2023-03-18T22:33:20Z',
#   'git_url': 'git://github.com/0xbadidea/public-apis.git',
#   'ssh_url': 'git@github.com:0xbadidea/public-apis.git',
#   'clone_url': 'https://github.com/0xbadidea/public-apis.git',
#   'svn_url': 'https://github.com/0xbadidea/public-apis',
#   'homepage': 'http://public-apis.org',
#   'size': 4948,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 617292999,
#   'node_id': 'R_kgDOJMskxw',
#   'name': 'public-apis',
#   'full_name': 'pawan230890/public-apis',
#   'private': False,
#   'owner': {'login': 'pawan230890',
#    'id': 11487642,
#    'node_id': 'MDQ6VXNlcjExNDg3NjQy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11487642?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pawan230890',
#    'html_url': 'https://github.com/pawan230890',
#    'followers_url': 'https://api.github.com/users/pawan230890/followers',
#    'following_url': 'https://api.github.com/users/pawan230890/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/pawan230890/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/pawan230890/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/pawan230890/subscriptions',
#    'organizations_url': 'https://api.github.com/users/pawan230890/orgs',
#    'repos_url': 'https://api.github.com/users/pawan230890/repos',
#    'events_url': 'https://api.github.com/users/pawan230890/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/pawan230890/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/pawan230890/public-apis',
#   'description': 'A collective list of free APIs',
#   'fork': True,
#   'url': 'https://api.github.com/repos/pawan230890/public-apis',
#   'forks_url': 'https://api.github.com/repos/pawan230890/public-apis/forks',
#   'keys_url': 'https://api.github.com/repos/pawan230890/public-apis/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/pawan230890/public-apis/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/pawan230890/public-apis/teams',
#   'hooks_url': 'https://api.github.com/repos/pawan230890/public-apis/hooks',
#   'issue_events_url': 'https://api.github.com/repos/pawan230890/public-apis/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/pawan230890/public-apis/events',
#   'assignees_url': 'https://api.github.com/repos/pawan230890/public-apis/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/pawan230890/public-apis/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/pawan230890/public-apis/tags',
#   'blobs_url': 'https://api.github.com/repos/pawan230890/public-apis/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/pawan230890/public-apis/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/pawan230890/public-apis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/pawan230890/public-apis/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/pawan230890/public-apis/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/pawan230890/public-apis/languages',
#   'stargazers_url': 'https://api.github.com/repos/pawan230890/public-apis/stargazers',
#   'contributors_url': 'https://api.github.com/repos/pawan230890/public-apis/contributors',
#   'subscribers_url': 'https://api.github.com/repos/pawan230890/public-apis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/pawan230890/public-apis/subscription',
#   'commits_url': 'https://api.github.com/repos/pawan230890/public-apis/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/pawan230890/public-apis/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/pawan230890/public-apis/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/pawan230890/public-apis/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/pawan230890/public-apis/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/pawan230890/public-apis/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/pawan230890/public-apis/merges',
#   'archive_url': 'https://api.github.com/repos/pawan230890/public-apis/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/pawan230890/public-apis/downloads',
#   'issues_url': 'https://api.github.com/repos/pawan230890/public-apis/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/pawan230890/public-apis/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/pawan230890/public-apis/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/pawan230890/public-apis/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/pawan230890/public-apis/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/pawan230890/public-apis/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/pawan230890/public-apis/deployments',
#   'created_at': '2023-03-22T04:41:17Z',
#   'updated_at': '2023-03-22T04:31:01Z',
#   'pushed_at': '2023-03-18T22:33:20Z',
#   'git_url': 'git://github.com/pawan230890/public-apis.git',
#   'ssh_url': 'git@github.com:pawan230890/public-apis.git',
#   'clone_url': 'https://github.com/pawan230890/public-apis.git',
#   'svn_url': 'https://github.com/pawan230890/public-apis',
#   'homepage': 'http://public-apis.org',
#   'size': 4948,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 617289869,
#   'node_id': 'R_kgDOJMsYjQ',
#   'name': 'public-apis',
#   'full_name': 'kottbtor/public-apis',
#   'private': False,
#   'owner': {'login': 'kottbtor',
#    'id': 93493064,
#    'node_id': 'U_kgDOBZKXSA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/93493064?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kottbtor',
#    'html_url': 'https://github.com/kottbtor',
#    'followers_url': 'https://api.github.com/users/kottbtor/followers',
#    'following_url': 'https://api.github.com/users/kottbtor/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kottbtor/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kottbtor/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kottbtor/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kottbtor/orgs',
#    'repos_url': 'https://api.github.com/users/kottbtor/repos',
#    'events_url': 'https://api.github.com/users/kottbtor/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kottbtor/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/kottbtor/public-apis',
#   'description': 'A collective list of free APIs',
#   'fork': True,
#   'url': 'https://api.github.com/repos/kottbtor/public-apis',
#   'forks_url': 'https://api.github.com/repos/kottbtor/public-apis/forks',
#   'keys_url': 'https://api.github.com/repos/kottbtor/public-apis/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/kottbtor/public-apis/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/kottbtor/public-apis/teams',
#   'hooks_url': 'https://api.github.com/repos/kottbtor/public-apis/hooks',
#   'issue_events_url': 'https://api.github.com/repos/kottbtor/public-apis/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/kottbtor/public-apis/events',
#   'assignees_url': 'https://api.github.com/repos/kottbtor/public-apis/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/kottbtor/public-apis/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/kottbtor/public-apis/tags',
#   'blobs_url': 'https://api.github.com/repos/kottbtor/public-apis/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/kottbtor/public-apis/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/kottbtor/public-apis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/kottbtor/public-apis/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/kottbtor/public-apis/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/kottbtor/public-apis/languages',
#   'stargazers_url': 'https://api.github.com/repos/kottbtor/public-apis/stargazers',
#   'contributors_url': 'https://api.github.com/repos/kottbtor/public-apis/contributors',
#   'subscribers_url': 'https://api.github.com/repos/kottbtor/public-apis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/kottbtor/public-apis/subscription',
#   'commits_url': 'https://api.github.com/repos/kottbtor/public-apis/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/kottbtor/public-apis/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/kottbtor/public-apis/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/kottbtor/public-apis/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/kottbtor/public-apis/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/kottbtor/public-apis/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/kottbtor/public-apis/merges',
#   'archive_url': 'https://api.github.com/repos/kottbtor/public-apis/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/kottbtor/public-apis/downloads',
#   'issues_url': 'https://api.github.com/repos/kottbtor/public-apis/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/kottbtor/public-apis/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/kottbtor/public-apis/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/kottbtor/public-apis/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/kottbtor/public-apis/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/kottbtor/public-apis/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/kottbtor/public-apis/deployments',
#   'created_at': '2023-03-22T04:27:26Z',
#   'updated_at': '2023-03-22T04:08:57Z',
#   'pushed_at': '2023-03-18T22:33:20Z',
#   'git_url': 'git://github.com/kottbtor/public-apis.git',
#   'ssh_url': 'git@github.com:kottbtor/public-apis.git',
#   'clone_url': 'https://github.com/kottbtor/public-apis.git',
#   'svn_url': 'https://github.com/kottbtor/public-apis',
#   'homepage': 'http://public-apis.org',
#   'size': 4948,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 617278774,
#   'node_id': 'R_kgDOJMrtNg',
#   'name': 'public-apis',
#   'full_name': 'cbrown0523/public-apis',
#   'private': False,
#   'owner': {'login': 'cbrown0523',
#    'id': 70735840,
#    'node_id': 'MDQ6VXNlcjcwNzM1ODQw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/70735840?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbrown0523',
#    'html_url': 'https://github.com/cbrown0523',
#    'followers_url': 'https://api.github.com/users/cbrown0523/followers',
#    'following_url': 'https://api.github.com/users/cbrown0523/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbrown0523/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbrown0523/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbrown0523/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbrown0523/orgs',
#    'repos_url': 'https://api.github.com/users/cbrown0523/repos',
#    'events_url': 'https://api.github.com/users/cbrown0523/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbrown0523/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/cbrown0523/public-apis',
#   'description': 'A collective list of free APIs',
#   'fork': True,
#   'url': 'https://api.github.com/repos/cbrown0523/public-apis',
#   'forks_url': 'https://api.github.com/repos/cbrown0523/public-apis/forks',
#   'keys_url': 'https://api.github.com/repos/cbrown0523/public-apis/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/cbrown0523/public-apis/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/cbrown0523/public-apis/teams',
#   'hooks_url': 'https://api.github.com/repos/cbrown0523/public-apis/hooks',
#   'issue_events_url': 'https://api.github.com/repos/cbrown0523/public-apis/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/cbrown0523/public-apis/events',
#   'assignees_url': 'https://api.github.com/repos/cbrown0523/public-apis/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/cbrown0523/public-apis/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/cbrown0523/public-apis/tags',
#   'blobs_url': 'https://api.github.com/repos/cbrown0523/public-apis/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/cbrown0523/public-apis/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/cbrown0523/public-apis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/cbrown0523/public-apis/git/trees{/sha}',
# ...
#   'hooks_url': 'https://api.github.com/repos/norato777/public-apis/hooks',
#   'issue_events_url': 'https://api.github.com/repos/norato777/public-apis/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/norato777/public-apis/events',
#   'assignees_url': 'https://api.github.com/repos/norato777/public-apis/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/norato777/public-apis/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/norato777/public-apis/tags',
#   'blobs_url': 'https://api.github.com/repos/norato777/public-apis/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/norato777/public-apis/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/norato777/public-apis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/norato777/public-apis/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/norato777/public-apis/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/norato777/public-apis/languages',
#   'stargazers_url': 'https://api.github.com/repos/norato777/public-apis/stargazers',
#   'contributors_url': 'https://api.github.com/repos/norato777/public-apis/contributors',
#   'subscribers_url': 'https://api.github.com/repos/norato777/public-apis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/norato777/public-apis/subscription',
#   'commits_url': 'https://api.github.com/repos/norato777/public-apis/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/norato777/public-apis/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/norato777/public-apis/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/norato777/public-apis/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/norato777/public-apis/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/norato777/public-apis/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/norato777/public-apis/merges',
#   'archive_url': 'https://api.github.com/repos/norato777/public-apis/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/norato777/public-apis/downloads',
#   'issues_url': 'https://api.github.com/repos/norato777/public-apis/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/norato777/public-apis/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/norato777/public-apis/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/norato777/public-apis/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/norato777/public-apis/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/norato777/public-apis/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/norato777/public-apis/deployments',
#   'created_at': '2023-03-20T20:43:00Z',
#   'updated_at': '2023-03-20T20:38:13Z',
#   'pushed_at': '2023-03-18T22:33:20Z',
#   'git_url': 'git://github.com/norato777/public-apis.git',
#   'ssh_url': 'git@github.com:norato777/public-apis.git',
#   'clone_url': 'https://github.com/norato777/public-apis.git',
#   'svn_url': 'https://github.com/norato777/public-apis',
#   'homepage': 'http://public-apis.org',
#   'size': 4948,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 616635111,
#   'node_id': 'R_kgDOJMEa5w',
#   'name': 'free-public-apis',
#   'full_name': 'derrick-enam-azameti/free-public-apis',
#   'private': False,
#   'owner': {'login': 'derrick-enam-azameti',
#    'id': 72652138,
#    'node_id': 'MDQ6VXNlcjcyNjUyMTM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72652138?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/derrick-enam-azameti',
#    'html_url': 'https://github.com/derrick-enam-azameti',
#    'followers_url': 'https://api.github.com/users/derrick-enam-azameti/followers',
#    'following_url': 'https://api.github.com/users/derrick-enam-azameti/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/derrick-enam-azameti/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/derrick-enam-azameti/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/derrick-enam-azameti/subscriptions',
#    'organizations_url': 'https://api.github.com/users/derrick-enam-azameti/orgs',
#    'repos_url': 'https://api.github.com/users/derrick-enam-azameti/repos',
#    'events_url': 'https://api.github.com/users/derrick-enam-azameti/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/derrick-enam-azameti/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/derrick-enam-azameti/free-public-apis',
#   'description': 'A collective list of free APIs',
#   'fork': True,
#   'url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis',
#   'forks_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/forks',
#   'keys_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/teams',
#   'hooks_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/hooks',
#   'issue_events_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/events',
#   'assignees_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/tags',
#   'blobs_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/languages',
#   'stargazers_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/stargazers',
#   'contributors_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/contributors',
#   'subscribers_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/subscription',
#   'commits_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/merges',
#   'archive_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/downloads',
#   'issues_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/derrick-enam-azameti/free-public-apis/deployments',
#   'created_at': '2023-03-20T19:20:39Z',
#   'updated_at': '2023-03-20T19:19:40Z',
#   'pushed_at': '2023-03-18T22:33:20Z',
#   'git_url': 'git://github.com/derrick-enam-azameti/free-public-apis.git',
#   'ssh_url': 'git@github.com:derrick-enam-azameti/free-public-apis.git',
#   'clone_url': 'https://github.com/derrick-enam-azameti/free-public-apis.git',
#   'svn_url': 'https://github.com/derrick-enam-azameti/free-public-apis',
#   'homepage': 'http://public-apis.org',
#   'size': 4948,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 616523120,
#   'node_id': 'R_kgDOJL9lcA',
#   'name': 'public-apis',
#   'full_name': 'mateuszrog/public-apis',
#   'private': False,
#   'owner': {'login': 'mateuszrog',
#    'id': 97434756,
#    'node_id': 'U_kgDOBc68hA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97434756?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mateuszrog',
#    'html_url': 'https://github.com/mateuszrog',
#    'followers_url': 'https://api.github.com/users/mateuszrog/followers',
#    'following_url': 'https://api.github.com/users/mateuszrog/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mateuszrog/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mateuszrog/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mateuszrog/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mateuszrog/orgs',
#    'repos_url': 'https://api.github.com/users/mateuszrog/repos',
#    'events_url': 'https://api.github.com/users/mateuszrog/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mateuszrog/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/mateuszrog/public-apis',
#   'description': 'A collective list of free APIs',
#   'fork': True,
#   'url': 'https://api.github.com/repos/mateuszrog/public-apis',
#   'forks_url': 'https://api.github.com/repos/mateuszrog/public-apis/forks',
#   'keys_url': 'https://api.github.com/repos/mateuszrog/public-apis/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/mateuszrog/public-apis/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/mateuszrog/public-apis/teams',
#   'hooks_url': 'https://api.github.com/repos/mateuszrog/public-apis/hooks',
#   'issue_events_url': 'https://api.github.com/repos/mateuszrog/public-apis/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/mateuszrog/public-apis/events',
#   'assignees_url': 'https://api.github.com/repos/mateuszrog/public-apis/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/mateuszrog/public-apis/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/mateuszrog/public-apis/tags',
#   'blobs_url': 'https://api.github.com/repos/mateuszrog/public-apis/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/mateuszrog/public-apis/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/mateuszrog/public-apis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/mateuszrog/public-apis/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/mateuszrog/public-apis/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/mateuszrog/public-apis/languages',
#   'stargazers_url': 'https://api.github.com/repos/mateuszrog/public-apis/stargazers',
#   'contributors_url': 'https://api.github.com/repos/mateuszrog/public-apis/contributors',
#   'subscribers_url': 'https://api.github.com/repos/mateuszrog/public-apis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/mateuszrog/public-apis/subscription',
#   'commits_url': 'https://api.github.com/repos/mateuszrog/public-apis/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/mateuszrog/public-apis/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/mateuszrog/public-apis/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/mateuszrog/public-apis/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/mateuszrog/public-apis/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/mateuszrog/public-apis/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/mateuszrog/public-apis/merges',
#   'archive_url': 'https://api.github.com/repos/mateuszrog/public-apis/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/mateuszrog/public-apis/downloads',
#   'issues_url': 'https://api.github.com/repos/mateuszrog/public-apis/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/mateuszrog/public-apis/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/mateuszrog/public-apis/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/mateuszrog/public-apis/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/mateuszrog/public-apis/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/mateuszrog/public-apis/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/mateuszrog/public-apis/deployments',
#   'created_at': '2023-03-20T14:53:42Z',
#   'updated_at': '2023-03-20T14:32:08Z',
#   'pushed_at': '2023-03-18T22:33:20Z',
#   'git_url': 'git://github.com/mateuszrog/public-apis.git',
#   'ssh_url': 'git@github.com:mateuszrog/public-apis.git',
#   'clone_url': 'https://github.com/mateuszrog/public-apis.git',
#   'svn_url': 'https://github.com/mateuszrog/public-apis',
#   'homepage': 'http://public-apis.org',
#   'size': 4948,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'}]

# %%
import pandas as pd
df = pd.DataFrame(response)
df
# Out:
#            id       node_id              name  \
# 0   617620885  R_kgDOJNAllQ       public-apis
# 1   617573550  R_kgDOJM9srg       public-apis
# 2   617554069  R_kgDOJM8glQ   999-public-apis
# 3   617462013  R_kgDOJM24_Q       public-apis
# 4   617436610  R_kgDOJM1Vwg       public-apis
# 5   617317994  R_kgDOJMuGag       public-apis
# 6   617292999  R_kgDOJMskxw       public-apis
# 7   617289869  R_kgDOJMsYjQ       public-apis
# 8   617278774  R_kgDOJMrtNg       public-apis
# 9   617240991  R_kgDOJMpZnw       public-apis
# 10  617227530  R_kgDOJMolCg       public-apis
# 11  617223206  R_kgDOJMoUJg       public-apis
# 12  617193483  R_kgDOJMmgCw       public-apis
# 13  617174700  R_kgDOJMlWrA       public-apis
# 14  617147075  R_kgDOJMjqww       public-apis
# 15  617144864  R_kgDOJMjiIA       public-apis
# 16  616959732  R_kgDOJMYO9A       public-apis
# 17  616919423  R_kgDOJMVxfw     public-apis00
# 18  616917393  R_kgDOJMVpkQ       public-apis
# 19  616907438  R_kgDOJMVCrg       public-apis
# 20  616896342  R_kgDOJMUXVg       public-apis
# 21  616861219  R_kgDOJMSOIw       public-apis
# 22  616855281  R_kgDOJMR28Q       public-apis
# 23  616853927  R_kgDOJMRxpw       public-apis
# 24  616822719  R_kgDOJMP3vw       public-apis
# 25  616797513  R_kgDOJMOVSQ       public-apis
# 26  616697823  R_kgDOJMIP3w       public-apis
# 27  616663555  R_kgDOJMGKAw       public-apis
# 28  616635111  R_kgDOJMEa5w  free-public-apis
# 29  616523120  R_kgDOJL9lcA       public-apis
#
#                                 full_name  private  \
# 0                    Xavi1250/public-apis    False
# 1                 stavares843/public-apis    False
# 2              Maoshanwen/999-public-apis    False
# 3                  Psycoguana/public-apis    False
# 4               PetrVakulenko/public-apis    False
# 5                   0xbadidea/public-apis    False
# 6                 pawan230890/public-apis    False
# 7                    kottbtor/public-apis    False
# 8                  cbrown0523/public-apis    False
# 9                 ServentSAMA/public-apis    False
# 10             harrisonleon44/public-apis    False
# 11              IsraelPBSousa/public-apis    False
# 12                 enesgezici/public-apis    False
# 13                    ethiraj/public-apis    False
# 14                   pharaoh1/public-apis    False
# 15                  fsndzomga/public-apis    False
# 16                     rajrdj/public-apis    False
# 17      blueThistle-bouquet/public-apis00    False
# 18                  Kazemix09/public-apis    False
# 19                Oluwakamiye/public-apis    False
# 20                  valdir-ti/public-apis    False
# 21               ridabensalem/public-apis    False
# 22                   reidalex/public-apis    False
# 23              iswangjiaxing/public-apis    False
# 24                 goyalh4164/public-apis    False
# 25                  manish465/public-apis    False
# 26                 RaspiColas/public-apis    False
# 27                  norato777/public-apis    False
# 28  derrick-enam-azameti/free-public-apis    False
# 29                 mateuszrog/public-apis    False
#
#                                                 owner  \
# 0   {'login': 'Xavi1250', 'id': 119597527, 'node_i...
# 1   {'login': 'stavares843', 'id': 29093946, 'node...
# 2   {'login': 'Maoshanwen', 'id': 80189087, 'node_...
# 3   {'login': 'Psycoguana', 'id': 21992381, 'node_...
# 4   {'login': 'PetrVakulenko', 'id': 24455335, 'no...
# 5   {'login': '0xbadidea', 'id': 89309725, 'node_i...
# 6   {'login': 'pawan230890', 'id': 11487642, 'node...
# 7   {'login': 'kottbtor', 'id': 93493064, 'node_id...
# 8   {'login': 'cbrown0523', 'id': 70735840, 'node_...
# 9   {'login': 'ServentSAMA', 'id': 65692164, 'node...
# 10  {'login': 'harrisonleon44', 'id': 125705750, '...
# 11  {'login': 'IsraelPBSousa', 'id': 126954203, 'n...
# 12  {'login': 'enesgezici', 'id': 19204782, 'node_...
# 13  {'login': 'ethiraj', 'id': 6472672, 'node_id':...
# 14  {'login': 'pharaoh1', 'id': 8192522, 'node_id'...
# 15  {'login': 'fsndzomga', 'id': 101533724, 'node_...
# 16  {'login': 'rajrdj', 'id': 67227635, 'node_id':...
# 17  {'login': 'blueThistle-bouquet', 'id': 1242447...
# 18  {'login': 'Kazemix09', 'id': 128474954, 'node_...
# 19  {'login': 'Oluwakamiye', 'id': 17198941, 'node...
# 20  {'login': 'valdir-ti', 'id': 11434239, 'node_i...
# 21  {'login': 'ridabensalem', 'id': 87722869, 'nod...
# 22  {'login': 'reidalex', 'id': 65669221, 'node_id...
# 23  {'login': 'iswangjiaxing', 'id': 31096380, 'no...
# 24  {'login': 'goyalh4164', 'id': 98226383, 'node_...
# 25  {'login': 'manish465', 'id': 46858945, 'node_i...
# 26  {'login': 'RaspiColas', 'id': 38288344, 'node_...
# 27  {'login': 'norato777', 'id': 73761982, 'node_i...
# 28  {'login': 'derrick-enam-azameti', 'id': 726521...
# 29  {'login': 'mateuszrog', 'id': 97434756, 'node_...
#
#                                              html_url  \
# 0             https://github.com/Xavi1250/public-apis
# 1          https://github.com/stavares843/public-apis
# 2       https://github.com/Maoshanwen/999-public-apis
# 3           https://github.com/Psycoguana/public-apis
# 4        https://github.com/PetrVakulenko/public-apis
# 5            https://github.com/0xbadidea/public-apis
# 6          https://github.com/pawan230890/public-apis
# 7             https://github.com/kottbtor/public-apis
# 8           https://github.com/cbrown0523/public-apis
# 9          https://github.com/ServentSAMA/public-apis
# 10      https://github.com/harrisonleon44/public-apis
# 11       https://github.com/IsraelPBSousa/public-apis
# 12          https://github.com/enesgezici/public-apis
# 13             https://github.com/ethiraj/public-apis
# 14            https://github.com/pharaoh1/public-apis
# 15           https://github.com/fsndzomga/public-apis
# 16              https://github.com/rajrdj/public-apis
# 17  https://github.com/blueThistle-bouquet/public-...
# 18           https://github.com/Kazemix09/public-apis
# 19         https://github.com/Oluwakamiye/public-apis
# 20           https://github.com/valdir-ti/public-apis
# 21        https://github.com/ridabensalem/public-apis
# 22            https://github.com/reidalex/public-apis
# 23       https://github.com/iswangjiaxing/public-apis
# 24          https://github.com/goyalh4164/public-apis
# 25           https://github.com/manish465/public-apis
# 26          https://github.com/RaspiColas/public-apis
# 27           https://github.com/norato777/public-apis
# 28  https://github.com/derrick-enam-azameti/free-p...
# 29          https://github.com/mateuszrog/public-apis
#
#                        description  fork  \
# 0   A collective list of free APIs  True
# 1   A collective list of free APIs  True
# 2   A collective list of free APIs  True
# 3   A collective list of free APIs  True
# 4   A collective list of free APIs  True
# 5   A collective list of free APIs  True
# 6   A collective list of free APIs  True
# 7   A collective list of free APIs  True
# 8   A collective list of free APIs  True
# 9   A collective list of free APIs  True
# 10  A collective list of free APIs  True
# 11  A collective list of free APIs  True
# 12  A collective list of free APIs  True
# 13  A collective list of free APIs  True
# 14  A collective list of free APIs  True
# 15  A collective list of free APIs  True
# 16  A collective list of free APIs  True
# 17  A collective list of free APIs  True
# 18  A collective list of free APIs  True
# 19  A collective list of free APIs  True
# 20  A collective list of free APIs  True
# 21  A collective list of free APIs  True
# 22  A collective list of free APIs  True
# 23  A collective list of free APIs  True
# 24  A collective list of free APIs  True
# 25  A collective list of free APIs  True
# 26  A collective list of free APIs  True
# 27  A collective list of free APIs  True
# 28  A collective list of free APIs  True
# 29  A collective list of free APIs  True
#
#                                                   url  ...  \
# 0   https://api.github.com/repos/Xavi1250/public-apis  ...
# 1   https://api.github.com/repos/stavares843/publi...  ...
# 2   https://api.github.com/repos/Maoshanwen/999-pu...  ...
# 3   https://api.github.com/repos/Psycoguana/public...  ...
# 4   https://api.github.com/repos/PetrVakulenko/pub...  ...
# 5   https://api.github.com/repos/0xbadidea/public-...  ...
# 6   https://api.github.com/repos/pawan230890/publi...  ...
# 7   https://api.github.com/repos/kottbtor/public-apis  ...
# 8   https://api.github.com/repos/cbrown0523/public...  ...
# 9   https://api.github.com/repos/ServentSAMA/publi...  ...
# 10  https://api.github.com/repos/harrisonleon44/pu...  ...
# 11  https://api.github.com/repos/IsraelPBSousa/pub...  ...
# 12  https://api.github.com/repos/enesgezici/public...  ...
# 13   https://api.github.com/repos/ethiraj/public-apis  ...
# 14  https://api.github.com/repos/pharaoh1/public-apis  ...
# 15  https://api.github.com/repos/fsndzomga/public-...  ...
# 16    https://api.github.com/repos/rajrdj/public-apis  ...
# 17  https://api.github.com/repos/blueThistle-bouqu...  ...
# 18  https://api.github.com/repos/Kazemix09/public-...  ...
# 19  https://api.github.com/repos/Oluwakamiye/publi...  ...
# 20  https://api.github.com/repos/valdir-ti/public-...  ...
# 21  https://api.github.com/repos/ridabensalem/publ...  ...
# 22  https://api.github.com/repos/reidalex/public-apis  ...
# 23  https://api.github.com/repos/iswangjiaxing/pub...  ...
# 24  https://api.github.com/repos/goyalh4164/public...  ...
# 25  https://api.github.com/repos/manish465/public-...  ...
# 26  https://api.github.com/repos/RaspiColas/public...  ...
# 27  https://api.github.com/repos/norato777/public-...  ...
# 28  https://api.github.com/repos/derrick-enam-azam...  ...
# 29  https://api.github.com/repos/mateuszrog/public...  ...
#
#                                               license allow_forking  \
# 0   {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 1   {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 2   {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 3   {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 4   {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 5   {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 6   {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 7   {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 8   {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 9   {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 10  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 11  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 12  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 13  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 14  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 15  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 16  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 17  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 18  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 19  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 20  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 21  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 22  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 23  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 24  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 25  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 26  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 27  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 28  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 29  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
#
#    is_template web_commit_signoff_required topics visibility forks  \
# 0        False                       False     []     public     0
# 1        False                       False     []     public     0
# 2        False                       False     []     public     0
# 3        False                       False     []     public     0
# 4        False                       False     []     public     0
# 5        False                       False     []     public     0
# 6        False                       False     []     public     0
# 7        False                       False     []     public     0
# 8        False                       False     []     public     0
# 9        False                       False     []     public     0
# 10       False                       False     []     public     0
# 11       False                       False     []     public     0
# 12       False                       False     []     public     0
# 13       False                       False     []     public     0
# 14       False                       False     []     public     0
# 15       False                       False     []     public     0
# 16       False                       False     []     public     0
# 17       False                       False     []     public     0
# 18       False                       False     []     public     0
# 19       False                       False     []     public     0
# 20       False                       False     []     public     0
# 21       False                       False     []     public     0
# 22       False                       False     []     public     0
# 23       False                       False     []     public     0
# 24       False                       False     []     public     0
# 25       False                       False     []     public     0
# 26       False                       False     []     public     0
# 27       False                       False     []     public     0
# 28       False                       False     []     public     0
# 29       False                       False     []     public     0
#
#    open_issues watchers default_branch
# 0            0        0         master
# 1            0        0         master
# 2            0        0         master
# 3            0        0         master
# 4            0        0         master
# 5            0        0         master
# 6            0        0         master
# 7            0        0         master
# 8            0        0         master
# 9            0        0         master
# 10           0        0         master
# 11           0        1         master
# 12           0        0         master
# 13           0        0         master
# 14           0        0         master
# 15           0        0         master
# 16           0        0         master
# 17           0        0         master
# 18           0        0         master
# 19           0        0         master
# 20           0        0         master
# 21           0        0         master
# 22           0        0         master
# 23           0        0         master
# 24           0        0         master
# 25           0        0         master
# 26           0        0         master
# 27           0        0         master
# 28           0        0         master
# 29           0        0         master
#
# [30 rows x 79 columns]

# %% [markdown]
# ## API Clients

# %% [markdown]
# ### THIS IS FROM RAPIDAPI --> https://rapidapi.com/community/api/open-weather-map/

# %%
import requests

url = "https://airport-info.p.rapidapi.com/airport"

querystring = {"iata":"bcn"}

headers = {
"X-RapidAPI-Key": "NOT AGAIN",
"X-RapidAPI-Host": "airport-info.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)

# %%
response.json()

# %% [markdown]
# ### Insomnia

# %% [markdown]
# We see insomnia --> https://insomnia.rest/download

# %% [markdown]
# In insomnia we can save different apis to be able to call them with a click, I leave you screenshots

# %% [markdown]
# ![insomnia](../images/in_1.png)
# ![insomnia](../images/in_2.png)
# ![insomnia](../images/in_3.png)
# ![insomnia](../images/in_4.png)

# %% [markdown]
# ### Codes generated by insomnia

# %%
import requests

url = "https://api.chucknorris.io/jokes/random"

payload = ""
response = requests.request("GET", url, data=payload)

print(response.text)

# %% [markdown]
# ## Spotify

# %%
# Sign up as a developer
# Create an app
# Credentials: id & token (spotify: two steps)
# Use your token to do requests to things

# %%
# ALWAYS: limit your quests to 1 until you're sure the code works
# time.sleep(4): to give enough time not to over request within a time frame
# IP adress: 
    # restart your router
    # cached: incognito mode
    # Your phone data for one second 
    # VPN

# %%
url = "https://api.spotify.com/v1/playlists"

# %%
# 1. Sign up as a developer -> client_id & client_secret
# 2. Create an app (projects): tokens will be linked to this app
# 3: Get credentials for authentication -> token for requests

# %% [markdown]
# ### Load initial credentials

# %% [markdown]
# ### Get token from those initial credentials

# %% [markdown]
# ### With token, we can create the headers

# %% [markdown]
# ## Summary

# %% [markdown]
# ## Further materials

# %% [markdown]
# - [5 Simple-To-Use APIs for Beginners](https://dev.to/alanconstantino/5-simple-to-use-apis-for-beginners-2e0n)
# - [RapidAPI](https://rapidapi.com/category/Sports): access thousands of APIs!!
# - [More APIs](https://github.com/public-apis/public-apis)
