# %% [markdown]
# # Write code on notebooks

# %%
import pandas as pd

# %%
df = pd.read_csv ("https://raw.githubusercontent.com/datapackage-examples/sample-csv/master/sample.csv")

# %%
df.sample()
# Out:
#       header 0     header 1     header 2     header 3     header 4  \
# 3  row 4 col 0  row 4 col 1  row 4 col 2  row 4 col 3  row 4 col 4
#
#       header 5     header 6     header 7     header 8     header 9
# 3  row 4 col 5  row 4 col 6  row 4 col 7  row 4 col 8  row 4 col 9

# %%
df.columns = [i.capitalize().replace(" ", "-") for i in df.columns]

# %%
df.dropna(inplace=True)

# %% [markdown]
# # Encapsulate it in functions

# %%
def rename_and_na (df):
    """Description
    :arguments:
    return
    """
    df = pd.read_csv(df)
    df.columns = [i.capitalize().replace(" ", "-") for i in df.columns]
    df.dropna(inplace=True)
    return df

# %%
updated_df = rename_and_na ("https://raw.githubusercontent.com/datapackage-examples/sample-csv/master/sample.csv")

# %%
updated_df.sample()
# Out:
#       Header-0     Header-1     Header-2     Header-3     Header-4  \
# 5  row 6 col 0  row 6 col 1  row 6 col 2  row 6 col 3  row 6 col 4
#
#       Header-5     Header-6     Header-7     Header-8     Header-9
# 5  row 6 col 5  row 6 col 6  row 6 col 7  row 6 col 8  row 6 col 9

# %% [markdown]
# # Distribute the functions according to goal

# %% [markdown]
# ```python
# /src
#     cleaning.py
#     visualization.py
# /notebooks
#     notebook-1
#     notebook-2
#     notebook-3
# main.py
# .gitignore
# README.md
# ```

# %% [markdown]
# # Import them back into notebooks

# %%
import src.cleaning_1 as clean # 1
from src.cleaning_2 import * # 2
import src.cleaning_3 # 3

# %%
# 1. Calling alias.function()

# %%
clean.rename_and_na("https://raw.githubusercontent.com/datapackage-examples/sample-csv/master/sample.csv")
# Out:
#        Header-0      Header-1      Header-2      Header-3      Header-4  \
# 0   row 1 col 0   row 1 col 1   row 1 col 2   row 1 col 3   row 1 col 4
# 1   row 2 col 0   row 2 col 1   row 2 col 2   row 2 col 3   row 2 col 4
# 2   row 3 col 0   row 3 col 1   row 3 col 2   row 3 col 3   row 3 col 4
# 3   row 4 col 0   row 4 col 1   row 4 col 2   row 4 col 3   row 4 col 4
# 4   row 5 col 0   row 5 col 1   row 5 col 2   row 5 col 3   row 5 col 4
# 5   row 6 col 0   row 6 col 1   row 6 col 2   row 6 col 3   row 6 col 4
# 6   row 7 col 0   row 7 col 1   row 7 col 2   row 7 col 3   row 7 col 4
# 7   row 8 col 0   row 8 col 1   row 8 col 2   row 8 col 3   row 8 col 4
# 8   row 9 col 0   row 9 col 1   row 9 col 2   row 9 col 3   row 9 col 4
# 9  row 10 col 0  row 10 col 1  row 10 col 2  row 10 col 3  row 10 col 4
#
#        Header-5      Header-6      Header-7      Header-8      Header-9
# 0   row 1 col 5   row 1 col 6   row 1 col 7   row 1 col 8   row 1 col 9
# ...

# %%
# 2. Calling the function()

# %%
rename_and_na("https://raw.githubusercontent.com/datapackage-examples/sample-csv/master/sample.csv")
# Out:
#        Header-0      Header-1      Header-2      Header-3      Header-4  \
# 0   row 1 col 0   row 1 col 1   row 1 col 2   row 1 col 3   row 1 col 4
# 1   row 2 col 0   row 2 col 1   row 2 col 2   row 2 col 3   row 2 col 4
# 2   row 3 col 0   row 3 col 1   row 3 col 2   row 3 col 3   row 3 col 4
# 3   row 4 col 0   row 4 col 1   row 4 col 2   row 4 col 3   row 4 col 4
# 4   row 5 col 0   row 5 col 1   row 5 col 2   row 5 col 3   row 5 col 4
# 5   row 6 col 0   row 6 col 1   row 6 col 2   row 6 col 3   row 6 col 4
# 6   row 7 col 0   row 7 col 1   row 7 col 2   row 7 col 3   row 7 col 4
# 7   row 8 col 0   row 8 col 1   row 8 col 2   row 8 col 3   row 8 col 4
# 8   row 9 col 0   row 9 col 1   row 9 col 2   row 9 col 3   row 9 col 4
# 9  row 10 col 0  row 10 col 1  row 10 col 2  row 10 col 3  row 10 col 4
#
#        Header-5      Header-6      Header-7      Header-8      Header-9
# 0   row 1 col 5   row 1 col 6   row 1 col 7   row 1 col 8   row 1 col 9
# ...

# %%
# 3. Calling directory.module.function()

# %%
src.cleaning_3.rename_and_na("https://raw.githubusercontent.com/datapackage-examples/sample-csv/master/sample.csv")
# Out:
#        Header-0      Header-1      Header-2      Header-3      Header-4  \
# 0   row 1 col 0   row 1 col 1   row 1 col 2   row 1 col 3   row 1 col 4
# 1   row 2 col 0   row 2 col 1   row 2 col 2   row 2 col 3   row 2 col 4
# 2   row 3 col 0   row 3 col 1   row 3 col 2   row 3 col 3   row 3 col 4
# 3   row 4 col 0   row 4 col 1   row 4 col 2   row 4 col 3   row 4 col 4
# 4   row 5 col 0   row 5 col 1   row 5 col 2   row 5 col 3   row 5 col 4
# 5   row 6 col 0   row 6 col 1   row 6 col 2   row 6 col 3   row 6 col 4
# 6   row 7 col 0   row 7 col 1   row 7 col 2   row 7 col 3   row 7 col 4
# 7   row 8 col 0   row 8 col 1   row 8 col 2   row 8 col 3   row 8 col 4
# 8   row 9 col 0   row 9 col 1   row 9 col 2   row 9 col 3   row 9 col 4
# 9  row 10 col 0  row 10 col 1  row 10 col 2  row 10 col 3  row 10 col 4
#
#        Header-5      Header-6      Header-7      Header-8      Header-9
# 0   row 1 col 5   row 1 col 6   row 1 col 7   row 1 col 8   row 1 col 9
# ...

# %% [markdown]
# # Substite the code on your notebooks: imperative to functional

# %%
# From this

# %%
df = pd.read_csv ("https://raw.githubusercontent.com/datapackage-examples/sample-csv/master/sample.csv")

# %%
df.columns = [i.capitalize().replace(" ", "-") for i in df.columns]

# %%
df.dropna(inplace=True)

# %%
# To this

# %%
clean.rename_and_na("https://raw.githubusercontent.com/datapackage-examples/sample-csv/master/sample.csv")

# %% [markdown]
# # main.py
